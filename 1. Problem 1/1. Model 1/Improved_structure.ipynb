# %% [markdown]
# # Import packages and set seeds

# %%
#! pip install pyDOE

# %%
import torch
import torch.autograd as autograd         # computation graph
from torch import Tensor                  # tensor node in the computation graph
import torch.nn as nn                     # neural networks
import torch.optim as optim               # optimizers e.g. gradient descent, ADAM, etc.

import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from mpl_toolkits.axes_grid1 import make_axes_locatable
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.ticker
from scipy.interpolate import griddata

import numpy as np
import time
#from pyDOE import lhs         #Latin Hypercube Sampling
import scipy.io

import copy

#Set default dtype to float32
torch.set_default_dtype(torch.float)

#PyTorch random number generator
torch.manual_seed(1234)

# Random number generators in other libraries
np.random.seed(1234)

# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

print(device)

if device == 'cuda': 
    print(torch.cuda.get_device_name())
# Out:
# cuda

# %%
print(f"Device name: {torch.cuda.get_device_name(0)}")
# !nvidia-smi
# Out:
# Device name: NVIDIA A100-PCIE-40GB
# Fri Apr 15 04:33:20 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 510.47.03    Driver Version: 510.47.03    CUDA Version: 11.6     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA A100-PCI...  On   | 00000000:27:00.0 Off |                    0 |
# | N/A   62C    P0   234W / 250W |  37679MiB / 40960MiB |     90%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
# |   1  NVIDIA A100-PCI...  On   | 00000000:28:00.0 Off |                    0 |
# | N/A   57C    P0    91W / 250W |  36855MiB / 40960MiB |    100%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
# |   2  NVIDIA A100-PCI...  On   | 00000000:43:00.0 Off |                    0 |
# | N/A   57C    P0    87W / 250W |  36801MiB / 40960MiB |    100%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
# |   3  NVIDIA A100-PCI...  On   | 00000000:44:00.0 Off |                    0 |
# | N/A   60C    P0    95W / 250W |  37259MiB / 40960MiB |    100%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
# |   4  NVIDIA A100-PCI...  On   | 00000000:A3:00.0 Off |                    0 |
# | N/A   36C    P0    49W / 250W |   2011MiB / 40960MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
# |   5  NVIDIA A100-PCI...  On   | 00000000:A4:00.0 Off |                    0 |
# | N/A   36C    P0    48W / 250W |      0MiB / 40960MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
# |   6  NVIDIA A100-PCI...  On   | 00000000:C3:00.0 Off |                    0 |
# | N/A   35C    P0    45W / 250W |      0MiB / 40960MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
# |   7  NVIDIA A100-PCI...  On   | 00000000:C4:00.0 Off |                    0 |
# | N/A   35C    P0    44W / 250W |      0MiB / 40960MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A     48524      C   ...s/scw1805-a100/bin/python    37673MiB |
# |    1   N/A  N/A     48525      C   ...s/scw1805-a100/bin/python    36853MiB |
# |    2   N/A  N/A     48526      C   ...s/scw1805-a100/bin/python    36799MiB |
# |    3   N/A  N/A     48527      C   ...s/scw1805-a100/bin/python    37257MiB |
# |    4   N/A  N/A     63129      C   ....conda/envs/ml/bin/python     2009MiB |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# # Data Preparation
# Training and Testing data is prepared from the solution file

# %%
data = np.load('final_data.npz') # Load data from file
keys = list(data.keys()) # all keys in the dictionary
print(keys)
nodes3D = data[keys[0]]
temperature = data[keys[1]]
boundary_nodal_coordinates3D = data[keys[2]]
boundary_solution = data[keys[3]]
# face3 = data[keys[4]]
# face4 = data[keys[5]]
# face5 = data[keys[6]]
# face6 = data[keys[7]]
print(np.shape(nodes3D))
print(np.shape(temperature))
print(np.shape(boundary_nodal_coordinates3D))
print(np.shape(boundary_solution))
# Out:
# ['nodes', 'temperature', 'boundary_nodal_coordinates', 'boundary_solution']
# (5800, 3)
# (5800, 1)
# (612, 3)
# (612, 1)

# %%
# cutting the useless third dimension where there is nothing to predict
nodes = nodes3D[:,[0,2]]
#temperature = temperature3D[:,[0,2]]
boundary_nodal_coordinates = boundary_nodal_coordinates3D[:,[0,2]]
#boundary_solution = boundary_solution3D[:,[0,2]]
print(np.shape(nodes))
print(np.shape(temperature))
print(np.shape(boundary_nodal_coordinates))
print(np.shape(boundary_solution))
# Out:
# (5800, 2)
# (5800, 1)
# (612, 2)
# (612, 1)

# %%
# Bounds shall be in accordance with nodes[x,y,z]
ub = nodes.max(axis=0)
lb = nodes.min(axis=0)
print(ub)
print(lb)
# Out:
# [0.5 1. ]
# [-0.5  0. ]

# %% [markdown]
# # Test data
# Just for comparing with the PINN predicted solution

# %%
''' X_u_test = [X[i],T[i]] [25600,2] for interpolation'''
#X_u_test = np.hstack((X.flatten()[:,None], T.flatten()[:,None]))

# Domain bounds
#lb = X_u_test[0]  # [-1. 0.]
#ub = X_u_test[-1] # [1.  0.99]

'''
   Fortran Style ('F') flatten,stacked column wise!
   u = [c1 
        c2
        .
        .
        cn]

   u =  [25600x1] 
'''
#u_true = usol.flatten('F')[:,None] 
X_u_test = nodes
u_true = temperature

# %% [markdown]
# # Training data

# %%
def trainingdata(N_u,N_f):

    '''Boundary Conditions'''

#     #Initial Condition -1 =< x =<1 and t = 0  
#     leftedge_x = np.hstack((X[0,:][:,None], T[0,:][:,None])) #L1
#     leftedge_u = usol[:,0][:,None]

#     #Boundary Condition x = -1 and 0 =< t =<1
#     bottomedge_x = np.hstack((X[:,0][:,None], T[:,0][:,None])) #L2
#     bottomedge_u = usol[-1,:][:,None]

#     #Boundary Condition x = 1 and 0 =< t =<1
#     topedge_x = np.hstack((X[:,-1][:,None], T[:,0][:,None])) #L3
#     topedge_u = usol[0,:][:,None]

#     all_X_u_train = np.vstack([leftedge_x, bottomedge_x, topedge_x]) # X_u_train [456,2] (456 = 256(L1)+100(L2)+100(L3))
#     all_u_train = np.vstack([leftedge_u, bottomedge_u, topedge_u])   #corresponding u [456x1]
    
    all_X_u_train = boundary_nodal_coordinates # all nodal coordinates
    all_u_train = boundary_solution # boundary condition solution
    #choose random N_u points for training
    # all_X_u_train.shape[0] = 34071
    #idx = np.random.choice(all_X_u_train.shape[0], N_u, replace=False) 

   # X_u_train = all_X_u_train[idx, :] #choose indices from  set 'idx' (x,t)
    #u_train = all_u_train[idx,:]      #choose corresponding u
    X_u_train = all_X_u_train
    u_train = all_u_train 
    
    '''Collocation Points'''

    # Latin Hypercube sampling for collocation points 
    # N_f sets of tuples(x,t)
   # X_f_train = lb + (ub-lb)*lhs(2,N_f) 
    #X_f_train = np.vstack((X_f_train, X_u_train)) # append training points to collocation points 
    # No Latin Hypercube sampling. Just put all the data
    
    X_f_train = nodes # nodal coordinates or collocation points
    return X_f_train, X_u_train, u_train

# %% [markdown]
# # Physics-informed neural network

# %%
class Sequentialmodel(nn.Module):
    def __init__(self, layers):
        super().__init__() #call __init__ from parent class to initialise the torch.nn.Module
              
        # Activation function
        self.activation = nn.Tanh()
        
        # Loss function
        # A help on why we are using mean reduction 
        # https://pytorch.org/docs/stable/generated/torch.nn.MSELoss.html
        self.loss_function = nn.MSELoss(reduction ='mean')
        
        # Initialise neural network as a list using nn.Modulelist 
        self.linears = nn.ModuleList([nn.Linear(layers[i], layers[i+1]) for i in range(len(layers)-1)])
        
        self.iter = 0 # Initialise iteration variable
        
        #
        # Alternatively:
        
        #*all layers are callable 
    
        #Simple linear Layers
        #self.fc1 = nn.Linear(2,50)
        #self.fc2 = nn.Linear(50,50)
        #self.fc3 = nn.Linear(50,50)
        #self.fc4 = nn.Linear(50,1)
        
        
        # Xavier Normal Initialization
        # std = gain * sqrt(2/(input_dim+output_dim))
        for i in range(len(layers)-1):
            
            # weights from a normal distribution with 
            # Recommended gain value for tanh = 5/3?
            nn.init.xavier_normal_(self.linears[i].weight.data, gain=1.0)
            
            # set biases to zero
            nn.init.zeros_(self.linears[i].bias.data)
    def forward(self,x):
        # Forward pass
        if torch.is_tensor(x) != True:         
            x = torch.from_numpy(x)                
        
        u_b = torch.from_numpy(ub).float().to(device)
        l_b = torch.from_numpy(lb).float().to(device)
                      
        #preprocessing input 
        x = (x - l_b)/(u_b - l_b) #feature scaling
        
        #convert to float
        a = x.float()
                        
             
        #Alternatively:
        
        #a = self.activation(self.fc1(a))
        #a = self.activation(self.fc2(a))
        #a = self.activation(self.fc3(a))
        #a = self.fc4(a)
        
        for i in range(len(layers)-2): # last layer is not activated
            
            z = self.linears[i](a)
                        
            a = self.activation(z)
            
        a = self.linears[-1](a) # linear feedforward no activation (y= mx+c)
        
        return a
        
    def loss_BC(self,x,y):
        # Boundary condition loss 
        # Splitting the forward pass and loss computation to visualise the pointwise loss
        forwarded_BC = self.forward(x)
        loss_u = self.loss_function(forwarded_BC,y)
                
        return loss_u

    def loss_PDE(self, x_to_train_f):
        
        #nu = 0.01/np.pi
        #k = 0.01  # thermal conductivity
        #
        # 3D heat conduction with constant k and no heat generation term
        # We don't need k
        # T_xx + T_yy + T_zz = 0
        # This is also known as the Laplace equation
        
        x_1_f = x_to_train_f[:,[0]]
        x_2_f = x_to_train_f[:,[1]]
                        
        g = x_to_train_f.clone()
                        
        g.requires_grad = True
        
        u = self.forward(g)
                
        #u_x_t = autograd.grad(u,g,torch.ones([x_to_train_f.shape[0], 1]).to(device), retain_graph=True, create_graph=True)[0]
                                
        #u_xx_tt = autograd.grad(u_x_t,g,torch.ones(x_to_train_f.shape).to(device), create_graph=True)[0]
                                                            
        #u_x = u_x_t[:,[0]]
        
        #u_t = u_x_t[:,[1]]
        
        #u_xx = u_xx_tt[:,[0]]
        # This is 2D problem
        # First derivative of u w.r.t to all inputs i.e. x, y and z
        u_x_y = autograd.grad(u,g,torch.ones([x_to_train_f.shape[0], 1]).to(device), retain_graph=True, create_graph=True)[0]
        # Second derivative of u w.r.t to all inputs i.e. x, y and z                        
        u_xx_yy = autograd.grad(u_x_y,g,torch.ones(x_to_train_f.shape).to(device), create_graph=True)[0]
        # Since there are 3 input vectors x,y and z                                                    
        u_xx = u_xx_yy[:,[0]]
        
        u_yy = u_xx_yy[:,[1]]
        
        #u_zz = u_xx_yy_zz[:,[2]]
                                        
        #f = u_t + (self.forward(g))*(u_x) - (nu)*u_xx 
        
        #loss_f = self.loss_function(f,f_hat)
        # PDE loss                                
        f = u_xx + u_yy #+ u_zz 
        
        loss_f = self.loss_function(f,f_hat) # f_hat is global variable in the main section
                
        return loss_f
    
    def loss(self,x,y,x_to_train_f):

        loss_u = self.loss_BC(x,y)
        loss_f = self.loss_PDE(x_to_train_f)
        
        loss_val = loss_u + loss_f
        
        return loss_val
     
    'callable for optimizer'                                       
    def closure(self):
        
        optimizer.zero_grad()
        
        loss = self.loss(X_u_train, u_train, X_f_train)
        
        loss.backward()
                
        self.iter += 1
        
        if self.iter % 100 == 0:

            error_vec, _ = PINN.test()
        
            print(loss,error_vec)

        return loss        
    
    'test neural network'
    def test(self):
                
        u_pred = self.forward(X_u_test_tensor)
        
        error_vec = torch.linalg.norm((u-u_pred),2)/torch.linalg.norm(u,2)        # Relative L2 Norm of the error (Vector)
        
        u_pred = u_pred.cpu().detach().numpy()
        
        #u_pred = np.reshape(u_pred,(256,100),order='F')
                
        return error_vec, u_pred

# %% [markdown]
# # Main

# %%
 
N_u = 100 #Total number of data points for 'u'
N_f = 10_000 #Total number of collocation points 
X_f_train_np_array, X_u_train_np_array, u_train_np_array = trainingdata(N_u,N_f)

# Convert numpy arrays to tensors 
X_f_train = torch.from_numpy(X_f_train_np_array).float().to(device)
X_u_train = torch.from_numpy(X_u_train_np_array).float().to(device)
u_train = torch.from_numpy(u_train_np_array).float().to(device)
X_u_test_tensor = torch.from_numpy(X_u_test).float().to(device)
u = torch.from_numpy(u_true).float().to(device)
f_hat = torch.zeros(X_f_train.shape[0],1).to(device)

layers = np.array([2,20,20,20,20,20,20,20,20,1]) # Units in hidden layers
#layers = np.array([3,50,50,50,50,1]) 
#layers = np.array([3,100,100,100,100,1]) 

PINN = Sequentialmodel(layers)
bestPINN = Sequentialmodel(layers) # this is our model with lowest training because PINNs don't have validation but testing error
# We do not need to assign this to a device as we will not train the bestPINN model.
PINN.to(device)
bestPINN.to(device)

params = list(PINN.parameters())

# Optimisation
# L-BFGS Optimiser
# optimizer = torch.optim.LBFGS(PINN.parameters(), lr=0.1, 
#                               max_iter = 5000, 
#                               max_eval = None, 
#                               tolerance_grad = 1e-05, 
#                               tolerance_change = 1e-09, 
#                               history_size = 100, 
#                               line_search_fn = 'strong_wolfe')

# start_time = time.time()

# optimizer.step(PINN.closure)

# Adam optimiser
optimizer = optim.Adam(PINN.parameters(), lr=0.001,betas=(0.8, 0.999), eps=1e-08, weight_decay=0, amsgrad=False)

max_iter = 30000

start_time = time.time()
BC_loss_array = np.zeros(max_iter)
PDE_loss_array = np.zeros(max_iter)
total_loss_array = np.zeros(max_iter)
test_error_array = np.zeros(max_iter)
#flag = np.zeros(max_iter,dtype=bool)

for i in range(max_iter):
    BC_loss =  PINN.loss_BC(X_u_train, u_train) # BC loss
    PDE_loss = PINN.loss_PDE(X_f_train) # PDE loss

    total_loss = BC_loss + PDE_loss #PINN.loss(BC_loss, PDE_loss, X_f_train)
           
    optimizer.zero_grad()     # zeroes the gradient in each epoch
    
    total_loss.backward() # backprop the total loss and store in .grad()
    optimizer.step() # update parameters
    
    error_vec, _ = PINN.test() # save time by not predicting the u_pred in each iteration
    BC_loss_array [i] = BC_loss
    PDE_loss_array[i] = PDE_loss
    total_loss_array[i] = total_loss  
    test_error_array[i] = error_vec
    
    
    if i % (max_iter/100) == 0:
        print(f" Epoch: {i+1} \t BC Loss: {BC_loss:0.4f}\t PDE Loss: {PDE_loss:0.4f} \t Loss: {total_loss:0.4f} \t Test Error: {error_vec:0.4f}")
    if total_loss < 1e-3:
        print(f'Loss converged in {i} Epochs')
        break
        
    # Choosing the best model
    
    if i>=2 and test_error_array[i] < np.amin(test_error_array[0:(i-1)]): # if current total loss is the minimum in the test loss array for all previous iterations i.e. [0,i-1]
        # for i<2, in test_error_array[0:(i-1)] is i-1 is negative (i=0) and null (i=1), so better avoid first two iteration for selecting the best model
        #flag[i] = True
        print(f'Best model found at {i} th iteration with test error = {error_vec:0.4f}')
        bestPINN.load_state_dict(copy.deepcopy(PINN.state_dict())) # then the current PINN model is the best model, copying the state dictionary to the bestPINN
        # https://discuss.pytorch.org/t/copy-deepcopy-vs-clone/55022
        best_iter = i # save the best iteration to put it on the test error plot
    #else:
    #    flag[i]=False
#     if i % (max_iter/10) == 0:
#         error_vec, _ = PINN.test()
#         print(loss,error_vec)

else:
    print('Training finished')
    elapsed = time.time() - start_time                
    print('Training time: %.2f' % (elapsed))
    print(f"Final loss: {total_loss}")




''' Model Accuracy ''' 
best_error_vec, best_u_pred = bestPINN.test() # use the best model to evaluate the test error
final_error_vec, final_u_pred = PINN.test()
print('Best Test Error: %.5f'  % (best_error_vec))
print('Final Test Error: %.5f'  % (final_error_vec))
# Out:
#  Epoch: 1 	 BC Loss: 0.5202	 PDE Loss: 0.0627 	 Loss: 0.5829 	 Test Error: 0.9009
# Best model found at 2 th iteration with test error = 0.7668
# Best model found at 3 th iteration with test error = 0.7191
# Best model found at 4 th iteration with test error = 0.6773
# Best model found at 5 th iteration with test error = 0.6383
# Best model found at 6 th iteration with test error = 0.6020
# Best model found at 7 th iteration with test error = 0.5697
# Best model found at 8 th iteration with test error = 0.5428
# Best model found at 9 th iteration with test error = 0.5227
# Best model found at 10 th iteration with test error = 0.5094
# Best model found at 11 th iteration with test error = 0.5021
# Best model found at 12 th iteration with test error = 0.4994
# Best model found at 13 th iteration with test error = 0.5002
# Best model found at 20 th iteration with test error = 0.4983
# Best model found at 21 th iteration with test error = 0.4966
# Best model found at 22 th iteration with test error = 0.4956
# Best model found at 23 th iteration with test error = 0.4951
# Best model found at 24 th iteration with test error = 0.4948
# Best model found at 25 th iteration with test error = 0.4946
# Best model found at 26 th iteration with test error = 0.4943
# Best model found at 27 th iteration with test error = 0.4939
# Best model found at 28 th iteration with test error = 0.4934
# Best model found at 29 th iteration with test error = 0.4928
# Best model found at 30 th iteration with test error = 0.4921
# Best model found at 31 th iteration with test error = 0.4915
# Best model found at 32 th iteration with test error = 0.4909
# Best model found at 33 th iteration with test error = 0.4904
# Best model found at 34 th iteration with test error = 0.4899
# Best model found at 35 th iteration with test error = 0.4895
# Best model found at 36 th iteration with test error = 0.4890
# Best model found at 37 th iteration with test error = 0.4885
# Best model found at 38 th iteration with test error = 0.4880
# Best model found at 39 th iteration with test error = 0.4874
# Best model found at 40 th iteration with test error = 0.4868
# Best model found at 41 th iteration with test error = 0.4862
# Best model found at 42 th iteration with test error = 0.4856
# Best model found at 43 th iteration with test error = 0.4850
# Best model found at 44 th iteration with test error = 0.4845
# Best model found at 45 th iteration with test error = 0.4840
# Best model found at 46 th iteration with test error = 0.4835
# Best model found at 47 th iteration with test error = 0.4830
# Best model found at 48 th iteration with test error = 0.4826
# Best model found at 49 th iteration with test error = 0.4822
# Best model found at 50 th iteration with test error = 0.4818
# Best model found at 51 th iteration with test error = 0.4814
# Best model found at 52 th iteration with test error = 0.4811
# Best model found at 53 th iteration with test error = 0.4808
# Best model found at 54 th iteration with test error = 0.4804
# Best model found at 55 th iteration with test error = 0.4800
# Best model found at 56 th iteration with test error = 0.4797
# Best model found at 57 th iteration with test error = 0.4793
# Best model found at 58 th iteration with test error = 0.4789
# Best model found at 59 th iteration with test error = 0.4785
# Best model found at 60 th iteration with test error = 0.4783
# Best model found at 61 th iteration with test error = 0.4779
# Best model found at 62 th iteration with test error = 0.4776
# Best model found at 63 th iteration with test error = 0.4773
# Best model found at 64 th iteration with test error = 0.4771
# Best model found at 65 th iteration with test error = 0.4767
# Best model found at 66 th iteration with test error = 0.4765
# Best model found at 67 th iteration with test error = 0.4762
# Best model found at 68 th iteration with test error = 0.4758
# Best model found at 69 th iteration with test error = 0.4755
# Best model found at 70 th iteration with test error = 0.4753
# Best model found at 71 th iteration with test error = 0.4748
# Best model found at 72 th iteration with test error = 0.4745
# Best model found at 73 th iteration with test error = 0.4743
# Best model found at 74 th iteration with test error = 0.4738
# Best model found at 75 th iteration with test error = 0.4735
# Best model found at 76 th iteration with test error = 0.4732
# Best model found at 77 th iteration with test error = 0.4727
# Best model found at 78 th iteration with test error = 0.4725
# Best model found at 79 th iteration with test error = 0.4719
# Best model found at 80 th iteration with test error = 0.4716
# Best model found at 81 th iteration with test error = 0.4712
# Best model found at 82 th iteration with test error = 0.4708
# Best model found at 83 th iteration with test error = 0.4705
# Best model found at 84 th iteration with test error = 0.4699
# Best model found at 85 th iteration with test error = 0.4703
# Best model found at 86 th iteration with test error = 0.4695
# Best model found at 88 th iteration with test error = 0.4689
# Best model found at 89 th iteration with test error = 0.4684
# Best model found at 90 th iteration with test error = 0.4678
# Best model found at 91 th iteration with test error = 0.4674
# Best model found at 93 th iteration with test error = 0.4666
# Best model found at 94 th iteration with test error = 0.4663
# Best model found at 95 th iteration with test error = 0.4655
# Best model found at 96 th iteration with test error = 0.4650
# Best model found at 97 th iteration with test error = 0.4650
# Best model found at 98 th iteration with test error = 0.4641
# Best model found at 99 th iteration with test error = 0.4642
# Best model found at 100 th iteration with test error = 0.4633
# Best model found at 105 th iteration with test error = 0.4621
# Best model found at 106 th iteration with test error = 0.4620
# Best model found at 108 th iteration with test error = 0.4619
# Best model found at 109 th iteration with test error = 0.4594
# Best model found at 110 th iteration with test error = 0.4599
# Best model found at 112 th iteration with test error = 0.4576
# Best model found at 113 th iteration with test error = 0.4569
# Best model found at 114 th iteration with test error = 0.4574
# Best model found at 115 th iteration with test error = 0.4562
# Best model found at 116 th iteration with test error = 0.4565
# Best model found at 117 th iteration with test error = 0.4543
# Best model found at 118 th iteration with test error = 0.4540
# Best model found at 119 th iteration with test error = 0.4524
# Best model found at 120 th iteration with test error = 0.4525
# Best model found at 121 th iteration with test error = 0.4512
# Best model found at 126 th iteration with test error = 0.4483
# Best model found at 133 th iteration with test error = 0.4468
# Best model found at 135 th iteration with test error = 0.4453
# Best model found at 136 th iteration with test error = 0.4445
# Best model found at 138 th iteration with test error = 0.4427
# Best model found at 139 th iteration with test error = 0.4418
# Best model found at 140 th iteration with test error = 0.4426
# Best model found at 141 th iteration with test error = 0.4396
# Best model found at 142 th iteration with test error = 0.4385
# Best model found at 143 th iteration with test error = 0.4390
# Best model found at 144 th iteration with test error = 0.4363
# Best model found at 145 th iteration with test error = 0.4355
# Best model found at 146 th iteration with test error = 0.4350
# Best model found at 147 th iteration with test error = 0.4326
# Best model found at 148 th iteration with test error = 0.4332
# Best model found at 149 th iteration with test error = 0.4303
# Best model found at 158 th iteration with test error = 0.4295
# Best model found at 163 th iteration with test error = 0.4286
# Best model found at 166 th iteration with test error = 0.4273
# Best model found at 167 th iteration with test error = 0.4264
# Best model found at 169 th iteration with test error = 0.4236
# Best model found at 170 th iteration with test error = 0.4226
# Best model found at 172 th iteration with test error = 0.4209
# Best model found at 173 th iteration with test error = 0.4193
# Best model found at 174 th iteration with test error = 0.4209
# Best model found at 175 th iteration with test error = 0.4179
# Best model found at 176 th iteration with test error = 0.4157
# Best model found at 177 th iteration with test error = 0.4173
# Best model found at 178 th iteration with test error = 0.4134
# Best model found at 179 th iteration with test error = 0.4126
# Best model found at 180 th iteration with test error = 0.4130
# Best model found at 181 th iteration with test error = 0.4093
# Best model found at 182 th iteration with test error = 0.4121
# Best model found at 183 th iteration with test error = 0.4069
# Best model found at 184 th iteration with test error = 0.4093
# Best model found at 185 th iteration with test error = 0.4046
# Best model found at 186 th iteration with test error = 0.4054
# Best model found at 187 th iteration with test error = 0.4028
# Best model found at 188 th iteration with test error = 0.4028
# Best model found at 189 th iteration with test error = 0.4003
# Best model found at 190 th iteration with test error = 0.4028
# Best model found at 191 th iteration with test error = 0.3978
# Best model found at 220 th iteration with test error = 0.3952
# Best model found at 221 th iteration with test error = 0.3934
# Best model found at 222 th iteration with test error = 0.3941
# Best model found at 223 th iteration with test error = 0.3920
# Best model found at 224 th iteration with test error = 0.3886
# Best model found at 225 th iteration with test error = 0.3877
# Best model found at 226 th iteration with test error = 0.3870
# Best model found at 227 th iteration with test error = 0.3832
# Best model found at 228 th iteration with test error = 0.3834
# Best model found at 229 th iteration with test error = 0.3821
# Best model found at 230 th iteration with test error = 0.3787
# Best model found at 231 th iteration with test error = 0.3779
# Best model found at 232 th iteration with test error = 0.3764
# Best model found at 233 th iteration with test error = 0.3741
# Best model found at 234 th iteration with test error = 0.3729
# Best model found at 235 th iteration with test error = 0.3711
# Best model found at 236 th iteration with test error = 0.3698
# Best model found at 237 th iteration with test error = 0.3673
# Best model found at 238 th iteration with test error = 0.3665
# Best model found at 239 th iteration with test error = 0.3640
# Best model found at 240 th iteration with test error = 0.3641
# Best model found at 241 th iteration with test error = 0.3600
# Best model found at 242 th iteration with test error = 0.3598
# Best model found at 243 th iteration with test error = 0.3574
# Best model found at 244 th iteration with test error = 0.3557
# Best model found at 245 th iteration with test error = 0.3540
# Best model found at 246 th iteration with test error = 0.3509
# Best model found at 247 th iteration with test error = 0.3512
# Best model found at 248 th iteration with test error = 0.3462
# Best model found at 249 th iteration with test error = 0.3479
# Best model found at 250 th iteration with test error = 0.3411
# Best model found at 252 th iteration with test error = 0.3361
# Best model found at 267 th iteration with test error = 0.3338
# Best model found at 270 th iteration with test error = 0.3231
# Best model found at 271 th iteration with test error = 0.3233
# Best model found at 273 th iteration with test error = 0.3086
# Best model found at 274 th iteration with test error = 0.3081
# Best model found at 276 th iteration with test error = 0.2968
# Best model found at 277 th iteration with test error = 0.2987
# Best model found at 278 th iteration with test error = 0.2954
# Best model found at 279 th iteration with test error = 0.2854
# Best model found at 281 th iteration with test error = 0.2793
# Best model found at 283 th iteration with test error = 0.2785
# Best model found at 289 th iteration with test error = 0.2710
# Best model found at 293 th iteration with test error = 0.2628
# Best model found at 297 th iteration with test error = 0.2576
# Best model found at 298 th iteration with test error = 0.2478
#  Epoch: 301 	 BC Loss: 0.0922	 PDE Loss: 0.0123 	 Loss: 0.1045 	 Test Error: 0.2561
# Best model found at 306 th iteration with test error = 0.2416
# Best model found at 313 th iteration with test error = 0.2331
# Best model found at 316 th iteration with test error = 0.2247
# Best model found at 320 th iteration with test error = 0.2164
# Best model found at 321 th iteration with test error = 0.2147
# Best model found at 323 th iteration with test error = 0.2125
# Best model found at 329 th iteration with test error = 0.2094
# Best model found at 330 th iteration with test error = 0.2067
# Best model found at 331 th iteration with test error = 0.2029
# Best model found at 332 th iteration with test error = 0.1995
# Best model found at 348 th iteration with test error = 0.1977
# Best model found at 349 th iteration with test error = 0.1921
# Best model found at 350 th iteration with test error = 0.1956
# Best model found at 355 th iteration with test error = 0.1861
# Best model found at 356 th iteration with test error = 0.1848
# Best model found at 358 th iteration with test error = 0.1833
# Best model found at 376 th iteration with test error = 0.1762
# Best model found at 384 th iteration with test error = 0.1758
# Best model found at 385 th iteration with test error = 0.1729
# Best model found at 386 th iteration with test error = 0.1737
# Best model found at 391 th iteration with test error = 0.1724
# Best model found at 392 th iteration with test error = 0.1721
# Best model found at 393 th iteration with test error = 0.1704
# Best model found at 394 th iteration with test error = 0.1705
# Best model found at 395 th iteration with test error = 0.1701
# Best model found at 415 th iteration with test error = 0.1701
# Best model found at 416 th iteration with test error = 0.1697
# Best model found at 422 th iteration with test error = 0.1688
# Best model found at 439 th iteration with test error = 0.1685
# Best model found at 451 th iteration with test error = 0.1676
# Best model found at 452 th iteration with test error = 0.1683
# Best model found at 459 th iteration with test error = 0.1673
# Best model found at 460 th iteration with test error = 0.1672
# Best model found at 511 th iteration with test error = 0.1671
# Best model found at 512 th iteration with test error = 0.1671
# Best model found at 521 th iteration with test error = 0.1671
# Best model found at 555 th iteration with test error = 0.1666
#  Epoch: 601 	 BC Loss: 0.0575	 PDE Loss: 0.0034 	 Loss: 0.0609 	 Test Error: 0.1729
# Best model found at 748 th iteration with test error = 0.1666
#  Epoch: 901 	 BC Loss: 0.0571	 PDE Loss: 0.0015 	 Loss: 0.0587 	 Test Error: 0.1683
# Best model found at 924 th iteration with test error = 0.1663
# Best model found at 1034 th iteration with test error = 0.1662
# Best model found at 1039 th iteration with test error = 0.1659
# Best model found at 1040 th iteration with test error = 0.1660
#  Epoch: 1201 	 BC Loss: 0.0575	 PDE Loss: 0.0010 	 Loss: 0.0585 	 Test Error: 0.1792
# Best model found at 1310 th iteration with test error = 0.1658
# Best model found at 1440 th iteration with test error = 0.1656
#  Epoch: 1501 	 BC Loss: 0.0574	 PDE Loss: 0.0031 	 Loss: 0.0605 	 Test Error: 0.1720
# Best model found at 1554 th iteration with test error = 0.1655
#  Epoch: 1801 	 BC Loss: 0.0585	 PDE Loss: 0.0006 	 Loss: 0.0590 	 Test Error: 0.1801
# Best model found at 1827 th iteration with test error = 0.1654
# Best model found at 1832 th iteration with test error = 0.1651
#  Epoch: 2101 	 BC Loss: 0.0575	 PDE Loss: 0.0009 	 Loss: 0.0584 	 Test Error: 0.1745
# Best model found at 2274 th iteration with test error = 0.1649
#  Epoch: 2401 	 BC Loss: 0.0565	 PDE Loss: 0.0004 	 Loss: 0.0569 	 Test Error: 0.1684
# Best model found at 2473 th iteration with test error = 0.1647
# Best model found at 2623 th iteration with test error = 0.1647
#  Epoch: 2701 	 BC Loss: 0.0576	 PDE Loss: 0.0005 	 Loss: 0.0581 	 Test Error: 0.1784
# Best model found at 2965 th iteration with test error = 0.1647
# Best model found at 2966 th iteration with test error = 0.1646
#  Epoch: 3001 	 BC Loss: 0.0564	 PDE Loss: 0.0021 	 Loss: 0.0585 	 Test Error: 0.1653
# Best model found at 3097 th iteration with test error = 0.1641
#  Epoch: 3301 	 BC Loss: 0.0562	 PDE Loss: 0.0002 	 Loss: 0.0564 	 Test Error: 0.1670
# Best model found at 3401 th iteration with test error = 0.1639
#  Epoch: 3601 	 BC Loss: 0.0604	 PDE Loss: 0.0018 	 Loss: 0.0622 	 Test Error: 0.2004
# Best model found at 3640 th iteration with test error = 0.1639
#  Epoch: 3901 	 BC Loss: 0.0590	 PDE Loss: 0.0018 	 Loss: 0.0608 	 Test Error: 0.1909
# Best model found at 4097 th iteration with test error = 0.1636
#  Epoch: 4201 	 BC Loss: 0.0560	 PDE Loss: 0.0002 	 Loss: 0.0562 	 Test Error: 0.1655
#  Epoch: 4501 	 BC Loss: 0.0564	 PDE Loss: 0.0002 	 Loss: 0.0566 	 Test Error: 0.1686
# Best model found at 4582 th iteration with test error = 0.1635
#  Epoch: 4801 	 BC Loss: 0.0564	 PDE Loss: 0.0004 	 Loss: 0.0568 	 Test Error: 0.1675
# Best model found at 4883 th iteration with test error = 0.1631
# Best model found at 4910 th iteration with test error = 0.1629
#  Epoch: 5101 	 BC Loss: 0.0561	 PDE Loss: 0.0017 	 Loss: 0.0578 	 Test Error: 0.1651
# Best model found at 5132 th iteration with test error = 0.1629
#  Epoch: 5401 	 BC Loss: 0.0560	 PDE Loss: 0.0003 	 Loss: 0.0563 	 Test Error: 0.1641
#  Epoch: 5701 	 BC Loss: 0.0557	 PDE Loss: 0.0002 	 Loss: 0.0559 	 Test Error: 0.1645
# Best model found at 5801 th iteration with test error = 0.1627
# Best model found at 5980 th iteration with test error = 0.1625
# Best model found at 5985 th iteration with test error = 0.1623
#  Epoch: 6001 	 BC Loss: 0.0557	 PDE Loss: 0.0037 	 Loss: 0.0594 	 Test Error: 0.1631
#  Epoch: 6301 	 BC Loss: 0.0559	 PDE Loss: 0.0007 	 Loss: 0.0566 	 Test Error: 0.1655
# Best model found at 6441 th iteration with test error = 0.1619
# Best model found at 6442 th iteration with test error = 0.1620
#  Epoch: 6601 	 BC Loss: 0.0558	 PDE Loss: 0.0004 	 Loss: 0.0562 	 Test Error: 0.1672
#  Epoch: 6901 	 BC Loss: 0.0553	 PDE Loss: 0.0001 	 Loss: 0.0554 	 Test Error: 0.1636
# Best model found at 6943 th iteration with test error = 0.1616
#  Epoch: 7201 	 BC Loss: 0.0553	 PDE Loss: 0.0005 	 Loss: 0.0557 	 Test Error: 0.1631
#  Epoch: 7501 	 BC Loss: 0.0570	 PDE Loss: 0.0037 	 Loss: 0.0608 	 Test Error: 0.1829
# Best model found at 7695 th iteration with test error = 0.1615
# Best model found at 7697 th iteration with test error = 0.1615
# Best model found at 7699 th iteration with test error = 0.1614
# Best model found at 7732 th iteration with test error = 0.1608
#  Epoch: 7801 	 BC Loss: 0.0552	 PDE Loss: 0.0009 	 Loss: 0.0560 	 Test Error: 0.1617
#  Epoch: 8101 	 BC Loss: 0.0551	 PDE Loss: 0.0031 	 Loss: 0.0581 	 Test Error: 0.1643
# Best model found at 8344 th iteration with test error = 0.1606
# Best model found at 8350 th iteration with test error = 0.1605
# Best model found at 8353 th iteration with test error = 0.1604
#  Epoch: 8401 	 BC Loss: 0.0552	 PDE Loss: 0.0007 	 Loss: 0.0559 	 Test Error: 0.1645
# Best model found at 8496 th iteration with test error = 0.1603
#  Epoch: 8701 	 BC Loss: 0.0561	 PDE Loss: 0.0014 	 Loss: 0.0575 	 Test Error: 0.1760
# Best model found at 8759 th iteration with test error = 0.1603
# Best model found at 8777 th iteration with test error = 0.1599
# Best model found at 8782 th iteration with test error = 0.1596
#  Epoch: 9001 	 BC Loss: 0.0551	 PDE Loss: 0.0014 	 Loss: 0.0565 	 Test Error: 0.1612
# Best model found at 9251 th iteration with test error = 0.1596
# Best model found at 9257 th iteration with test error = 0.1594
#  Epoch: 9301 	 BC Loss: 0.0544	 PDE Loss: 0.0002 	 Loss: 0.0547 	 Test Error: 0.1606
# Best model found at 9334 th iteration with test error = 0.1593
#  Epoch: 9601 	 BC Loss: 0.0543	 PDE Loss: 0.0002 	 Loss: 0.0544 	 Test Error: 0.1603
# Best model found at 9676 th iteration with test error = 0.1592
# Best model found at 9787 th iteration with test error = 0.1587
# Best model found at 9788 th iteration with test error = 0.1589
#  Epoch: 9901 	 BC Loss: 0.0549	 PDE Loss: 0.0013 	 Loss: 0.0562 	 Test Error: 0.1620
# Best model found at 9960 th iteration with test error = 0.1587
#  Epoch: 10201 	 BC Loss: 0.0541	 PDE Loss: 0.0003 	 Loss: 0.0544 	 Test Error: 0.1596
# Best model found at 10460 th iteration with test error = 0.1586
#  Epoch: 10501 	 BC Loss: 0.0542	 PDE Loss: 0.0044 	 Loss: 0.0586 	 Test Error: 0.1615
# Best model found at 10505 th iteration with test error = 0.1585
# Best model found at 10577 th iteration with test error = 0.1583
# Best model found at 10602 th iteration with test error = 0.1579
#  Epoch: 10801 	 BC Loss: 0.0543	 PDE Loss: 0.0007 	 Loss: 0.0550 	 Test Error: 0.1626
# Best model found at 10980 th iteration with test error = 0.1577
#  Epoch: 11101 	 BC Loss: 0.0544	 PDE Loss: 0.0029 	 Loss: 0.0574 	 Test Error: 0.1595
# Best model found at 11110 th iteration with test error = 0.1577
# Best model found at 11116 th iteration with test error = 0.1576
#  Epoch: 11401 	 BC Loss: 0.0536	 PDE Loss: 0.0013 	 Loss: 0.0549 	 Test Error: 0.1578
# Best model found at 11462 th iteration with test error = 0.1573
# Best model found at 11463 th iteration with test error = 0.1576
# Best model found at 11510 th iteration with test error = 0.1573
# Best model found at 11682 th iteration with test error = 0.1572
# Best model found at 11685 th iteration with test error = 0.1571
# Best model found at 11686 th iteration with test error = 0.1571
#  Epoch: 11701 	 BC Loss: 0.0533	 PDE Loss: 0.0003 	 Loss: 0.0537 	 Test Error: 0.1583
# Best model found at 11808 th iteration with test error = 0.1571
# Best model found at 11923 th iteration with test error = 0.1570
#  Epoch: 12001 	 BC Loss: 0.0536	 PDE Loss: 0.0011 	 Loss: 0.0547 	 Test Error: 0.1616
# Best model found at 12039 th iteration with test error = 0.1570
# Best model found at 12048 th iteration with test error = 0.1568
# Best model found at 12183 th iteration with test error = 0.1567
# Best model found at 12185 th iteration with test error = 0.1566
# Best model found at 12252 th iteration with test error = 0.1565
#  Epoch: 12301 	 BC Loss: 0.0544	 PDE Loss: 0.0012 	 Loss: 0.0555 	 Test Error: 0.1633
# Best model found at 12451 th iteration with test error = 0.1564
# Best model found at 12516 th iteration with test error = 0.1564
# Best model found at 12517 th iteration with test error = 0.1562
#  Epoch: 12601 	 BC Loss: 0.0530	 PDE Loss: 0.0008 	 Loss: 0.0538 	 Test Error: 0.1580
# Best model found at 12638 th iteration with test error = 0.1561
#  Epoch: 12901 	 BC Loss: 0.0529	 PDE Loss: 0.0004 	 Loss: 0.0533 	 Test Error: 0.1566
# Best model found at 12919 th iteration with test error = 0.1561
# Best model found at 12928 th iteration with test error = 0.1559
# Best model found at 13011 th iteration with test error = 0.1557
# Best model found at 13053 th iteration with test error = 0.1556
#  Epoch: 13201 	 BC Loss: 0.0525	 PDE Loss: 0.0023 	 Loss: 0.0548 	 Test Error: 0.1573
# Best model found at 13339 th iteration with test error = 0.1554
# Best model found at 13391 th iteration with test error = 0.1552
#  Epoch: 13501 	 BC Loss: 0.0526	 PDE Loss: 0.0017 	 Loss: 0.0543 	 Test Error: 0.1594
# Best model found at 13538 th iteration with test error = 0.1551
# Best model found at 13591 th iteration with test error = 0.1550
# Best model found at 13593 th iteration with test error = 0.1550
# Best model found at 13654 th iteration with test error = 0.1549
# Best model found at 13734 th iteration with test error = 0.1548
# Best model found at 13762 th iteration with test error = 0.1546
# Best model found at 13763 th iteration with test error = 0.1547
# Best model found at 13764 th iteration with test error = 0.1546
#  Epoch: 13801 	 BC Loss: 0.0544	 PDE Loss: 0.0051 	 Loss: 0.0595 	 Test Error: 0.1703
# Best model found at 13832 th iteration with test error = 0.1544
# Best model found at 13869 th iteration with test error = 0.1543
# Best model found at 13871 th iteration with test error = 0.1541
# Best model found at 14002 th iteration with test error = 0.1541
# Best model found at 14047 th iteration with test error = 0.1540
# Best model found at 14061 th iteration with test error = 0.1538
#  Epoch: 14101 	 BC Loss: 0.0535	 PDE Loss: 0.0012 	 Loss: 0.0546 	 Test Error: 0.1665
# Best model found at 14157 th iteration with test error = 0.1537
# Best model found at 14192 th iteration with test error = 0.1537
# Best model found at 14205 th iteration with test error = 0.1537
# Best model found at 14249 th iteration with test error = 0.1533
# Best model found at 14263 th iteration with test error = 0.1533
# Best model found at 14264 th iteration with test error = 0.1533
# Best model found at 14313 th iteration with test error = 0.1532
# Best model found at 14345 th iteration with test error = 0.1532
# Best model found at 14347 th iteration with test error = 0.1531
# Best model found at 14375 th iteration with test error = 0.1531
#  Epoch: 14401 	 BC Loss: 0.0510	 PDE Loss: 0.0007 	 Loss: 0.0516 	 Test Error: 0.1541
# Best model found at 14413 th iteration with test error = 0.1530
# Best model found at 14416 th iteration with test error = 0.1530
# Best model found at 14425 th iteration with test error = 0.1529
# Best model found at 14443 th iteration with test error = 0.1529
# Best model found at 14523 th iteration with test error = 0.1529
# Best model found at 14524 th iteration with test error = 0.1529
# Best model found at 14525 th iteration with test error = 0.1528
# Best model found at 14526 th iteration with test error = 0.1526
# Best model found at 14546 th iteration with test error = 0.1525
# Best model found at 14592 th iteration with test error = 0.1522
# Best model found at 14593 th iteration with test error = 0.1523
# Best model found at 14653 th iteration with test error = 0.1521
# Best model found at 14654 th iteration with test error = 0.1521
# Best model found at 14675 th iteration with test error = 0.1521
# Best model found at 14676 th iteration with test error = 0.1520
#  Epoch: 14701 	 BC Loss: 0.0502	 PDE Loss: 0.0012 	 Loss: 0.0515 	 Test Error: 0.1521
# Best model found at 14709 th iteration with test error = 0.1519
# Best model found at 14713 th iteration with test error = 0.1518
# Best model found at 14716 th iteration with test error = 0.1518
# Best model found at 14772 th iteration with test error = 0.1517
# Best model found at 14810 th iteration with test error = 0.1514
# Best model found at 14811 th iteration with test error = 0.1515
# Best model found at 14858 th iteration with test error = 0.1513
# Best model found at 14871 th iteration with test error = 0.1513
# Best model found at 14889 th iteration with test error = 0.1511
# Best model found at 14914 th iteration with test error = 0.1511
# Best model found at 14926 th iteration with test error = 0.1509
# Best model found at 14927 th iteration with test error = 0.1508
# Best model found at 14941 th iteration with test error = 0.1507
# Best model found at 14943 th iteration with test error = 0.1505
#  Epoch: 15001 	 BC Loss: 0.0518	 PDE Loss: 0.0034 	 Loss: 0.0553 	 Test Error: 0.1581
# Best model found at 15037 th iteration with test error = 0.1504
# Best model found at 15109 th iteration with test error = 0.1503
# Best model found at 15110 th iteration with test error = 0.1502
# Best model found at 15112 th iteration with test error = 0.1501
# Best model found at 15134 th iteration with test error = 0.1500
# Best model found at 15135 th iteration with test error = 0.1499
# Best model found at 15150 th iteration with test error = 0.1497
# Best model found at 15156 th iteration with test error = 0.1495
# Best model found at 15177 th iteration with test error = 0.1495
# Best model found at 15183 th iteration with test error = 0.1495
# Best model found at 15186 th iteration with test error = 0.1494
# Best model found at 15191 th iteration with test error = 0.1492
# Best model found at 15231 th iteration with test error = 0.1492
# Best model found at 15267 th iteration with test error = 0.1491
# Best model found at 15269 th iteration with test error = 0.1490
# Best model found at 15270 th iteration with test error = 0.1490
# Best model found at 15281 th iteration with test error = 0.1489
# Best model found at 15285 th iteration with test error = 0.1488
# Best model found at 15287 th iteration with test error = 0.1488
#  Epoch: 15301 	 BC Loss: 0.0514	 PDE Loss: 0.0027 	 Loss: 0.0541 	 Test Error: 0.1685
# Best model found at 15305 th iteration with test error = 0.1487
# Best model found at 15314 th iteration with test error = 0.1484
# Best model found at 15323 th iteration with test error = 0.1483
# Best model found at 15357 th iteration with test error = 0.1483
# Best model found at 15369 th iteration with test error = 0.1482
# Best model found at 15380 th iteration with test error = 0.1482
# Best model found at 15387 th iteration with test error = 0.1481
# Best model found at 15400 th iteration with test error = 0.1481
# Best model found at 15401 th iteration with test error = 0.1481
# Best model found at 15404 th iteration with test error = 0.1480
# Best model found at 15410 th iteration with test error = 0.1478
# Best model found at 15441 th iteration with test error = 0.1476
# Best model found at 15472 th iteration with test error = 0.1474
# Best model found at 15473 th iteration with test error = 0.1472
# Best model found at 15502 th iteration with test error = 0.1471
# Best model found at 15503 th iteration with test error = 0.1471
# Best model found at 15509 th iteration with test error = 0.1470
# Best model found at 15581 th iteration with test error = 0.1469
# Best model found at 15582 th iteration with test error = 0.1466
#  Epoch: 15601 	 BC Loss: 0.0477	 PDE Loss: 0.0018 	 Loss: 0.0495 	 Test Error: 0.1471
# Best model found at 15612 th iteration with test error = 0.1464
# Best model found at 15613 th iteration with test error = 0.1465
# Best model found at 15624 th iteration with test error = 0.1464
# Best model found at 15627 th iteration with test error = 0.1463
# Best model found at 15631 th iteration with test error = 0.1463
# Best model found at 15646 th iteration with test error = 0.1461
# Best model found at 15647 th iteration with test error = 0.1458
# Best model found at 15652 th iteration with test error = 0.1458
# Best model found at 15736 th iteration with test error = 0.1456
# Best model found at 15737 th iteration with test error = 0.1456
# Best model found at 15757 th iteration with test error = 0.1455
# Best model found at 15761 th iteration with test error = 0.1455
# Best model found at 15762 th iteration with test error = 0.1454
# Best model found at 15770 th iteration with test error = 0.1454
# Best model found at 15771 th iteration with test error = 0.1454
# Best model found at 15786 th iteration with test error = 0.1453
# Best model found at 15801 th iteration with test error = 0.1452
# Best model found at 15802 th iteration with test error = 0.1450
# Best model found at 15823 th iteration with test error = 0.1445
# Best model found at 15824 th iteration with test error = 0.1446
# Best model found at 15856 th iteration with test error = 0.1443
# Best model found at 15867 th iteration with test error = 0.1442
# Best model found at 15889 th iteration with test error = 0.1441
#  Epoch: 15901 	 BC Loss: 0.0479	 PDE Loss: 0.0022 	 Loss: 0.0501 	 Test Error: 0.1694
# Best model found at 15909 th iteration with test error = 0.1435
# Best model found at 15910 th iteration with test error = 0.1435
# Best model found at 15972 th iteration with test error = 0.1435
# Best model found at 15994 th iteration with test error = 0.1431
# Best model found at 15995 th iteration with test error = 0.1430
# Best model found at 15997 th iteration with test error = 0.1430
# Best model found at 15999 th iteration with test error = 0.1428
# Best model found at 16053 th iteration with test error = 0.1427
# Best model found at 16054 th iteration with test error = 0.1425
# Best model found at 16068 th iteration with test error = 0.1424
# Best model found at 16069 th iteration with test error = 0.1421
# Best model found at 16107 th iteration with test error = 0.1420
# Best model found at 16118 th iteration with test error = 0.1416
# Best model found at 16160 th iteration with test error = 0.1414
# Best model found at 16180 th iteration with test error = 0.1412
# Best model found at 16181 th iteration with test error = 0.1411
#  Epoch: 16201 	 BC Loss: 0.0460	 PDE Loss: 0.0009 	 Loss: 0.0469 	 Test Error: 0.1477
# Best model found at 16237 th iteration with test error = 0.1411
# Best model found at 16240 th iteration with test error = 0.1410
# Best model found at 16248 th iteration with test error = 0.1409
# Best model found at 16250 th iteration with test error = 0.1408
# Best model found at 16267 th iteration with test error = 0.1400
# Best model found at 16273 th iteration with test error = 0.1392
# Best model found at 16274 th iteration with test error = 0.1392
# Best model found at 16389 th iteration with test error = 0.1391
# Best model found at 16400 th iteration with test error = 0.1390
# Best model found at 16401 th iteration with test error = 0.1387
# Best model found at 16407 th iteration with test error = 0.1383
# Best model found at 16408 th iteration with test error = 0.1385
# Best model found at 16449 th iteration with test error = 0.1379
# Best model found at 16458 th iteration with test error = 0.1378
# Best model found at 16488 th iteration with test error = 0.1375
#  Epoch: 16501 	 BC Loss: 0.0405	 PDE Loss: 0.0015 	 Loss: 0.0420 	 Test Error: 0.1384
# Best model found at 16563 th iteration with test error = 0.1373
# Best model found at 16579 th iteration with test error = 0.1370
# Best model found at 16667 th iteration with test error = 0.1368
# Best model found at 16668 th iteration with test error = 0.1368
# Best model found at 16720 th iteration with test error = 0.1364
# Best model found at 16738 th iteration with test error = 0.1363
#  Epoch: 16801 	 BC Loss: 0.0380	 PDE Loss: 0.0027 	 Loss: 0.0407 	 Test Error: 0.1393
# Best model found at 16811 th iteration with test error = 0.1360
#  Epoch: 17101 	 BC Loss: 0.0376	 PDE Loss: 0.0017 	 Loss: 0.0394 	 Test Error: 0.1533
#  Epoch: 17401 	 BC Loss: 0.0321	 PDE Loss: 0.0012 	 Loss: 0.0332 	 Test Error: 0.1405
#  Epoch: 17701 	 BC Loss: 0.0319	 PDE Loss: 0.0067 	 Loss: 0.0386 	 Test Error: 0.1616
#  Epoch: 18001 	 BC Loss: 0.0295	 PDE Loss: 0.0013 	 Loss: 0.0308 	 Test Error: 0.1419
#  Epoch: 18301 	 BC Loss: 0.0282	 PDE Loss: 0.0018 	 Loss: 0.0300 	 Test Error: 0.1492
#  Epoch: 18601 	 BC Loss: 0.0269	 PDE Loss: 0.0011 	 Loss: 0.0280 	 Test Error: 0.1487
#  Epoch: 18901 	 BC Loss: 0.0268	 PDE Loss: 0.0025 	 Loss: 0.0293 	 Test Error: 0.1511
#  Epoch: 19201 	 BC Loss: 0.0259	 PDE Loss: 0.0014 	 Loss: 0.0273 	 Test Error: 0.1613
#  Epoch: 19501 	 BC Loss: 0.0251	 PDE Loss: 0.0044 	 Loss: 0.0295 	 Test Error: 0.1649
#  Epoch: 19801 	 BC Loss: 0.0238	 PDE Loss: 0.0006 	 Loss: 0.0245 	 Test Error: 0.1570
#  Epoch: 20101 	 BC Loss: 0.0236	 PDE Loss: 0.0020 	 Loss: 0.0256 	 Test Error: 0.1589
#  Epoch: 20401 	 BC Loss: 0.0263	 PDE Loss: 0.0009 	 Loss: 0.0272 	 Test Error: 0.1936
#  Epoch: 20701 	 BC Loss: 0.0246	 PDE Loss: 0.0006 	 Loss: 0.0252 	 Test Error: 0.1791
#  Epoch: 21001 	 BC Loss: 0.0232	 PDE Loss: 0.0007 	 Loss: 0.0239 	 Test Error: 0.1714
#  Epoch: 21301 	 BC Loss: 0.0248	 PDE Loss: 0.0433 	 Loss: 0.0681 	 Test Error: 0.1764
#  Epoch: 21601 	 BC Loss: 0.0217	 PDE Loss: 0.0006 	 Loss: 0.0222 	 Test Error: 0.1578
#  Epoch: 21901 	 BC Loss: 0.0216	 PDE Loss: 0.0020 	 Loss: 0.0236 	 Test Error: 0.1579
#  Epoch: 22201 	 BC Loss: 0.0214	 PDE Loss: 0.0010 	 Loss: 0.0224 	 Test Error: 0.1576
#  Epoch: 22501 	 BC Loss: 0.0263	 PDE Loss: 0.0028 	 Loss: 0.0292 	 Test Error: 0.1921
#  Epoch: 22801 	 BC Loss: 0.0217	 PDE Loss: 0.0020 	 Loss: 0.0237 	 Test Error: 0.1653
#  Epoch: 23101 	 BC Loss: 0.0219	 PDE Loss: 0.0040 	 Loss: 0.0259 	 Test Error: 0.1619
#  Epoch: 23401 	 BC Loss: 0.0236	 PDE Loss: 0.0019 	 Loss: 0.0255 	 Test Error: 0.1668
#  Epoch: 23701 	 BC Loss: 0.0202	 PDE Loss: 0.0025 	 Loss: 0.0227 	 Test Error: 0.1571
#  Epoch: 24001 	 BC Loss: 0.0203	 PDE Loss: 0.0172 	 Loss: 0.0375 	 Test Error: 0.1611
#  Epoch: 24301 	 BC Loss: 0.0206	 PDE Loss: 0.0032 	 Loss: 0.0238 	 Test Error: 0.1594
#  Epoch: 24601 	 BC Loss: 0.0199	 PDE Loss: 0.0014 	 Loss: 0.0213 	 Test Error: 0.1620
#  Epoch: 24901 	 BC Loss: 0.0209	 PDE Loss: 0.0013 	 Loss: 0.0223 	 Test Error: 0.1633
#  Epoch: 25201 	 BC Loss: 0.0194	 PDE Loss: 0.0007 	 Loss: 0.0201 	 Test Error: 0.1576
#  Epoch: 25501 	 BC Loss: 0.0196	 PDE Loss: 0.0013 	 Loss: 0.0209 	 Test Error: 0.1593
#  Epoch: 25801 	 BC Loss: 0.0199	 PDE Loss: 0.0008 	 Loss: 0.0207 	 Test Error: 0.1624
#  Epoch: 26101 	 BC Loss: 0.0195	 PDE Loss: 0.0012 	 Loss: 0.0207 	 Test Error: 0.1581
#  Epoch: 26401 	 BC Loss: 0.0195	 PDE Loss: 0.0003 	 Loss: 0.0198 	 Test Error: 0.1644
#  Epoch: 26701 	 BC Loss: 0.0189	 PDE Loss: 0.0003 	 Loss: 0.0192 	 Test Error: 0.1596
#  Epoch: 27001 	 BC Loss: 0.0200	 PDE Loss: 0.0014 	 Loss: 0.0214 	 Test Error: 0.1577
#  Epoch: 27301 	 BC Loss: 0.0227	 PDE Loss: 0.0020 	 Loss: 0.0246 	 Test Error: 0.1818
#  Epoch: 27601 	 BC Loss: 0.0196	 PDE Loss: 0.0032 	 Loss: 0.0228 	 Test Error: 0.1653
#  Epoch: 27901 	 BC Loss: 0.0194	 PDE Loss: 0.0006 	 Loss: 0.0200 	 Test Error: 0.1610
#  Epoch: 28201 	 BC Loss: 0.0205	 PDE Loss: 0.0016 	 Loss: 0.0220 	 Test Error: 0.1667
#  Epoch: 28501 	 BC Loss: 0.0183	 PDE Loss: 0.0035 	 Loss: 0.0218 	 Test Error: 0.1574
#  Epoch: 28801 	 BC Loss: 0.0183	 PDE Loss: 0.0017 	 Loss: 0.0200 	 Test Error: 0.1630
#  Epoch: 29101 	 BC Loss: 0.0192	 PDE Loss: 0.0057 	 Loss: 0.0248 	 Test Error: 0.1601
#  Epoch: 29401 	 BC Loss: 0.0186	 PDE Loss: 0.0019 	 Loss: 0.0206 	 Test Error: 0.1613
#  Epoch: 29701 	 BC Loss: 0.0183	 PDE Loss: 0.0012 	 Loss: 0.0195 	 Test Error: 0.1647
# Training finished
# Training time: 455.38
# Final loss: 0.026954645290970802
# Best Test Error: 0.13599
# Final Test Error: 0.16278

# %%
print(PINN.state_dict().keys())
print(PINN.state_dict()['linears.8.weight'])
print(bestPINN.state_dict()['linears.8.weight'])
# Out:
# odict_keys(['linears.0.weight', 'linears.0.bias', 'linears.1.weight', 'linears.1.bias', 'linears.2.weight', 'linears.2.bias', 'linears.3.weight', 'linears.3.bias', 'linears.4.weight', 'linears.4.bias', 'linears.5.weight', 'linears.5.bias', 'linears.6.weight', 'linears.6.bias', 'linears.7.weight', 'linears.7.bias', 'linears.8.weight', 'linears.8.bias'])
# tensor([[ 0.1858, -0.6027, -0.6295,  0.5536,  0.3924, -0.2499,  0.6984, -0.4760,
#          -0.3329,  0.1006, -0.0619, -0.4702, -0.4061, -0.7570, -0.2414, -0.4323,
#           0.4075,  0.9041,  0.2432, -0.7392]], device='cuda:0')
# tensor([[ 0.1408, -0.4777, -0.5022,  0.3270,  0.3509, -0.1525,  0.6684, -0.4419,
#          -0.2445,  0.1076, -0.0306, -0.2797, -0.1677, -0.7304, -0.0546, -0.2511,
#           0.3713,  0.7661,  0.1866, -0.5114]], device='cuda:0')

# %%
#solutionplot(u_pred,X_u_train.cpu().detach().numpy(),u_train.cpu().detach().numpy())

# %%
best_error_vec = best_error_vec.cpu().detach().numpy() # detach from GPU to CPU
final_error_vec = final_error_vec.cpu().detach().numpy() # detach from GPU to CPU

# %% [markdown]
# # Save arrays in npy file

# %%
## Saving list
# Input nodes: nodes
# ground truth: temperature
# max_iter = max_iter
# best iteration number: best_iter
# best model: best_error_vec, best_u_pred 
# final model: final_error_vec, final_u_pred
# Loss arrays: total_loss_array, BC_loss_array, PDE_loss_array, test_error_array

np.savez('Data_'+str(max_iter)+'_iteration.npz', 
         nodes = nodes, 
         temperature = temperature,
         max_iter = max_iter,
         best_error_vec = best_error_vec,
         best_u_pred = best_u_pred,
         final_error_vec = final_error_vec,
         final_u_pred = final_u_pred,
         best_iter = best_iter,
         PDE_loss_array = PDE_loss_array,
         BC_loss_array = BC_loss_array,
         total_loss_array = total_loss_array,
         test_error_array = test_error_array)

# %%
# Plot test error
#plt.figure(1,figsize=(8, 8), dpi=80)
plt.figure(1,dpi=300)
iter_array = np.arange(0,max_iter)
plt.plot(iter_array,test_error_array)
plt.plot([best_iter,best_iter],[0,best_error_vec],'o-k')
plt.xlabel('Epoch')
plt.ylabel('Test Error')
plt.legend(['Best error: ' +str(best_error_vec),'best iteration: '+str(best_iter)])
plt.ylim(bottom=0)  # https://matplotlib.org/3.5.0/api/_as_gen/matplotlib.pyplot.ylim.html
#plt.savefig('Test_error_'+str(max_iter)+'_iteration.jpg',dpi=150)
# Out:
# (0.0, 0.9459049522876739)

# %%
# Detach loss tensors
#print(np.shape(total_loss_array))
#print(total_loss_array)
#print(BC_loss_array)
#print(PDE_loss_array)
#print(np.array_equal(PDE_loss_array,BC_loss_array))

# %%
plt.figure(2, dpi=80)

iter_array = np.arange(0,max_iter)
plt.plot(iter_array,total_loss_array)
plt.plot(iter_array,BC_loss_array)
plt.plot(iter_array, PDE_loss_array)
plt.legend(['Total Loss','BC Loss','PDE Loss'])
plt.xlabel('Epoch')
plt.ylabel('Loss')
#plt.savefig('loss_'+str(max_iter)+'_iteration.jpg',dpi=150)
# Out:
# Text(0, 0.5, 'Loss')

# %%
# For plotting nicer plot we use plt.imshow().
# First we convert the unstructured data to mesh grid then use plt.imshow()

# %%
#print(np.shape(u_pred))
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
fig = plt.figure(dpi=300)
ax = fig.add_subplot(111)#, projection='3d')
n_points = 300
x = np.linspace(lb[0], ub[0], n_points)
y = np.linspace(lb[1], ub[1], n_points)
X, Y = np.meshgrid(x,y)

UU_star = griddata(nodes, temperature.flatten(), (X, Y), method='cubic')
sc = ax.imshow(UU_star, interpolation='nearest', cmap='jet', 
                  extent=[nodes[:,0].min(), nodes[:,0].max(), nodes[:,1].min(), nodes[:,1].max()], 
                  origin='lower', aspect='auto')

#sc = ax.scatter(nodes[:,0], nodes[:,1], c = temperature,s=3, cmap=cm.jet)
plt.colorbar(sc)
plt.xlabel('x')
plt.ylabel('y')
#ax.set_zlabel('z')
#plt.title('Temperature distribution')
#plt.savefig('Exact.jpg', dpi = 200)
# Out:
# Text(0, 0.5, 'y')

# %%
fig = plt.figure(figsize=(12,12))
ax = fig.add_subplot(111)#, projection='3d')
sc = ax.scatter(nodes[:,0], nodes[:,1], c = best_u_pred, cmap=cm.jet, vmin=0, vmax=1)
plt.colorbar(sc)
sc.cmap.set_under('k')
sc.cmap.set_over('k')
plt.xlabel('x')
plt.ylabel('y')
#ax.set_zlabel('z')
#plt.title('Temperature distribution')
#plt.savefig('Iteration_'+str(max_iter)+'_PINN_predicted.jpg', dpi = 200)
# Out:
# /tmp/ipykernel_63129/2919149.py:5: MatplotlibDeprecationWarning: You are modifying the state of a globally registered colormap. This has been deprecated since 3.3 and in 3.6, you will not be able to modify a registered colormap in-place. To remove this warning, you can make a copy of the colormap first. cmap = mpl.cm.get_cmap("jet").copy()
#   sc.cmap.set_under('k')
# /tmp/ipykernel_63129/2919149.py:6: MatplotlibDeprecationWarning: You are modifying the state of a globally registered colormap. This has been deprecated since 3.3 and in 3.6, you will not be able to modify a registered colormap in-place. To remove this warning, you can make a copy of the colormap first. cmap = mpl.cm.get_cmap("jet").copy()
#   sc.cmap.set_over('k')
# Text(0, 0.5, 'y')

# %%
fig = plt.figure(figsize=(12,12))
ax = fig.add_subplot(111)#, projection='3d')
 
sc = ax.scatter(nodes[:,0], nodes[:,1], c = abs(best_u_pred-temperature), cmap=cm.jet)
plt.colorbar(sc)
#sc.cmap.set_under('k')
#sc.cmap.set_over('k')
plt.xlabel('x')
plt.ylabel('y')
#ax.set_zlabel('z')
#plt.title('Temperature distribution')
#plt.savefig('iteration_'+str(max_iter)+'_absolute-error.jpg', dpi = 200)

# %% [markdown]
# # Continue training

# %%
#PINN.loss_BC(X_u_train, u_train)
#PINN.loss_PDE(X_f_train)

# %%
additional_iter = 20000

start_time = time.time()
BC_loss_array = np.zeros(additional_iter)
PDE_loss_array = np.zeros(additional_iter)
total_loss_array = np.zeros(additional_iter)

for i in range(additional_iter):
    # For updated model parameters of PINN() object
    BC_loss =  PINN.loss_BC(X_u_train, u_train) # BC loss
    PDE_loss = PINN.loss_PDE(X_f_train) # PDE loss

    total_loss = BC_loss + PDE_loss #PINN.loss(BC_loss, PDE_loss, X_f_train)
           
    optimizer.zero_grad()     # zeroes the gradient in each epoch
    
    total_loss.backward() # backprop the total loss and store in .grad()

    optimizer.step() # update parameters
    
    BC_loss_array [i] = BC_loss
    PDE_loss_array[i] = PDE_loss
    total_loss_array[i] = total_loss  
    
    if i % (additional_iter/10) == 0:
        print(f" Epoch: {i+1} \t BC Loss: {BC_loss:0.4f}\t PDE Loss: {PDE_loss:0.4f} \t Loss: {total_loss:0.4f}")
    if total_loss < 1: # compromise
        print(f'Loss converged in {i} Epochs ')
        break
#     if i % (max_iter/10) == 0:

#         error_vec, _ = PINN.test()

#         print(loss,error_vec)
else:
    print('Training finished')
    elapsed = time.time() - start_time                
    print('Training time: %.2f' % (elapsed))
    print(f"Final loss: {total_loss}")


''' Model Accuracy ''' 
error_vec, u_pred = PINN.test()

print('Test Error: %.5f'  % (error_vec))

# %%
plt.figure(1,figsize=(8, 8), dpi=80)

iter_array = np.arange(0,additional_iter)
plt.plot(iter_array,total_loss_array)
plt.plot(iter_array,BC_loss_array)
plt.plot(iter_array, PDE_loss_array)
plt.legend(['Total Loss','BC Loss','PDE Loss'])
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.savefig('loss_20000_Epoch.jpg',dpi=150)

# %%
print(np.shape(u_pred))

# %%
fig = plt.figure(figsize=(12,12))
ax = fig.add_subplot(111, projection='3d')
sc = ax.scatter(nodes[:,0], nodes[:,1], nodes[:,2], c = u_pred, cmap=cm.jet, vmin=100, vmax=200)
plt.colorbar(sc)
sc.cmap.set_under('k')
sc.cmap.set_over('k')
plt.xlabel('x')
plt.ylabel('y')
ax.set_zlabel('z')
plt.title('Temperature distribution')
plt.savefig('PINN_predicted.jpg', dpi = 200)

# %%
fig = plt.figure(figsize=(12,12))
ax = fig.add_subplot(111, projection='3d')
 
sc = ax.scatter(nodes[:,0], nodes[:,1], nodes[:,2], c = abs(u_pred-temperature), cmap=cm.jet)
plt.colorbar(sc)
#sc.cmap.set_under('k')
#sc.cmap.set_over('k')
plt.xlabel('x')
plt.ylabel('y')
ax.set_zlabel('z')
plt.title('Temperature distribution')
plt.savefig('absolute-error.jpg', dpi = 200)
