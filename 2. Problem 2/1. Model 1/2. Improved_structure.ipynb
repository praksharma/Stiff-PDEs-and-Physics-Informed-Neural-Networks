# %% [markdown]
# # Import packages and set seeds

# %%
#! pip install pyDOE

# %%
import torch
import torch.autograd as autograd         # computation graph
from torch import Tensor                  # tensor node in the computation graph
import torch.nn as nn                     # neural networks
import torch.optim as optim               # optimizers e.g. gradient descent, ADAM, etc.

import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from mpl_toolkits.axes_grid1 import make_axes_locatable
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.ticker
from scipy.interpolate import griddata
from matplotlib import cm

import numpy as np
import time
#from pyDOE import lhs         #Latin Hypercube Sampling
import scipy.io

import copy

#Set default dtype to float32
torch.set_default_dtype(torch.float)

#PyTorch random number generator
torch.manual_seed(1234)

# Random number generators in other libraries
np.random.seed(1234)

# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

print(device)

if device == 'cuda': 
    print(torch.cuda.get_device_name())
# Out:
# cuda

# %%
# !pwd
# Out:
# /scratch/s.1915438/temp/4. 3d heat conduction baseline pinn

# %%
# !bash -c 'echo $CUDA_VISIBLE_DEVICES'
# Out:
# 0

# %%
print(f"Device name: {torch.cuda.get_device_name(0)}")
# !nvidia-smi -i 0
# Out:
# Device name: NVIDIA A100-PCIE-40GB
# Tue May 31 15:20:14 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 510.47.03    Driver Version: 510.47.03    CUDA Version: 11.6     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA A100-PCI...  On   | 00000000:27:00.0 Off |                    0 |
# | N/A   41C    P0    47W / 250W |      2MiB / 40960MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# # Data Preparation
# Training and Testing data is prepared from the solution file

# %%
data = np.load('new_final_data.npz') # Load data from file
keys = list(data.keys()) # all keys in the dictionary
print(keys)
# Out:
# ['nodes', 'temperature', 'boundary_nodal_coordinates', 'boundary_solution']

# %%
# nodes = data[keys[0]] # collocation points
# boundary_nodal_coordinates = np.vstack([data[keys[1]], data[keys[2]], data[keys[3]]])  # boundary points
# boundary_solution = np.vstack([data[keys[4]], data[keys[5]], data[keys[6]]]) # prescribed BC
nodes = data[keys[0]]
temperature = data[keys[1]]/100-1
boundary_nodal_coordinates = data[keys[2]]
boundary_solution = data[keys[3]]/100-1
# # if the results are not good. Uncomment the following line to include the boundary smapled points in the collocation points. Although the domain bounds are already included in the collocation points while sampling.
# # nodes = np.vstack([nodes, boundary_nodal_coordinates])

# %%
#nodes = data[keys[0]]
#temperature = data[keys[1]]  # no true solution
#boundary_nodal_coordinates = data[keys[1]]
#boundary_solution = data[keys[2]]
# face3 = data[keys[4]]
# face4 = data[keys[5]]
# face5 = data[keys[6]]
# face6 = data[keys[7]]
print(np.shape(nodes))
print(np.shape(temperature))
print(np.shape(boundary_nodal_coordinates))
print(np.shape(boundary_solution))
# Out:
# (34071, 3)
# (34071, 1)
# (5814, 3)
# (5814, 1)

# %%
temperature.min(), temperature.max()
# Out:
# (0.0, 1.0)

# %%
boundary_solution.min(), boundary_solution.max()
# Out:
# (0.0, 1.0)

# %%
# # cutting the useless third dimension where there is nothing to predict
# nodes = nodes[:,[0,2]]
# #temperature = temperature3D[:,[0,2]]
# boundary_nodal_coordinates = boundary_nodal_coordinates[:,[0,2]]
# #boundary_solution = boundary_solution3D[:,[0,2]]
# print(np.shape(nodes))
# print(np.shape(temperature))
# print(np.shape(boundary_nodal_coordinates))
# print(np.shape(boundary_solution))

# %%
# Bounds shall be in accordance with nodes[x,y,z]
ub = nodes.max(axis=0)
lb = nodes.min(axis=0)

print('Variables :    x   y   z')
print('Lower bound : ', lb)
print('Upper bound : ', ub)
# Out:
# Variables :    x   y   z
# Lower bound :  [-0.5 -0.5  0. ]
# Upper bound :  [0.5 0.5 1. ]

# %% [markdown]
# # Test data
# Just for comparing with the PINN predicted solution

# %%
''' X_u_test = [X[i],T[i]] [25600,2] for interpolation'''
#X_u_test = np.hstack((X.flatten()[:,None], T.flatten()[:,None]))

# Domain bounds
#lb = X_u_test[0]  # [-1. 0.]
#ub = X_u_test[-1] # [1.  0.99]

'''
   Fortran Style ('F') flatten,stacked column wise!
   u = [c1 
        c2
        .
        .
        cn]

   u =  [25600x1] 
'''
#u_true = usol.flatten('F')[:,None] 
X_u_test = nodes
#u_true = temperature

# %% [markdown]
# # Training data

# %%
def trainingdata(N_u,N_f):

    '''Boundary Conditions'''

#     #Initial Condition -1 =< x =<1 and t = 0  
#     leftedge_x = np.hstack((X[0,:][:,None], T[0,:][:,None])) #L1
#     leftedge_u = usol[:,0][:,None]

#     #Boundary Condition x = -1 and 0 =< t =<1
#     bottomedge_x = np.hstack((X[:,0][:,None], T[:,0][:,None])) #L2
#     bottomedge_u = usol[-1,:][:,None]

#     #Boundary Condition x = 1 and 0 =< t =<1
#     topedge_x = np.hstack((X[:,-1][:,None], T[:,0][:,None])) #L3
#     topedge_u = usol[0,:][:,None]

#     all_X_u_train = np.vstack([leftedge_x, bottomedge_x, topedge_x]) # X_u_train [456,2] (456 = 256(L1)+100(L2)+100(L3))
#     all_u_train = np.vstack([leftedge_u, bottomedge_u, topedge_u])   #corresponding u [456x1]
    
    all_X_u_train = boundary_nodal_coordinates # all nodal coordinates
    all_u_train = boundary_solution # boundary condition solution
    #choose random N_u points for training
    # all_X_u_train.shape[0] = 34071
    #idx = np.random.choice(all_X_u_train.shape[0], N_u, replace=False) 

   # X_u_train = all_X_u_train[idx, :] #choose indices from  set 'idx' (x,t)
    #u_train = all_u_train[idx,:]      #choose corresponding u
    X_u_train = all_X_u_train
    u_train = all_u_train 
    
    '''Collocation Points'''

    # Latin Hypercube sampling for collocation points 
    # N_f sets of tuples(x,t)
   # X_f_train = lb + (ub-lb)*lhs(2,N_f) 
    #X_f_train = np.vstack((X_f_train, X_u_train)) # append training points to collocation points 
    # No Latin Hypercube sampling. Just put all the data
    
    X_f_train = nodes # nodal coordinates or collocation points
    return X_f_train, X_u_train, u_train

# %% [markdown]
# # Physics-informed neural network

# %%
class Sequentialmodel(nn.Module):
    def __init__(self, layers):
        super().__init__() #call __init__ from parent class to initialise the torch.nn.Module
              
        # Activation function
        self.activation = nn.Tanh()
        
        # Loss function
        # A help on why we are using mean reduction 
        # https://pytorch.org/docs/stable/generated/torch.nn.MSELoss.html
        self.loss_function = nn.MSELoss(reduction ='mean')
        
        # Initialise neural network as a list using nn.Modulelist 
        self.linears = nn.ModuleList([nn.Linear(layers[i], layers[i+1]) for i in range(len(layers)-1)])
        
        self.iter = 0 # Initialise iteration variable
        
        #
        # Alternatively:
        
        #*all layers are callable 
    
        #Simple linear Layers
        #self.fc1 = nn.Linear(2,50)
        #self.fc2 = nn.Linear(50,50)
        #self.fc3 = nn.Linear(50,50)
        #self.fc4 = nn.Linear(50,1)
        
        
        # Xavier Normal Initialization
        # std = gain * sqrt(2/(input_dim+output_dim))
        for i in range(len(layers)-1):
            
            # weights from a normal distribution with 
            # Recommended gain value for tanh = 5/3?
            nn.init.xavier_normal_(self.linears[i].weight.data, gain=1.0)
            
            # set biases to zero
            nn.init.zeros_(self.linears[i].bias.data)
    def forward(self,x):
        # Forward pass
        if torch.is_tensor(x) != True:         
            x = torch.from_numpy(x)                
        
        u_b = torch.from_numpy(ub).float().to(device)
        l_b = torch.from_numpy(lb).float().to(device)
                      
        #preprocessing input 
        x = (x - l_b)/(u_b - l_b) #feature scaling
        
        #convert to float
        a = x.float()
                        
             
        #Alternatively:
        
        #a = self.activation(self.fc1(a))
        #a = self.activation(self.fc2(a))
        #a = self.activation(self.fc3(a))
        #a = self.fc4(a)
        
        for i in range(len(layers)-2): # last layer is not activated
            
            z = self.linears[i](a)
                        
            a = self.activation(z)
            
        a = self.linears[-1](a) # linear feedforward no activation (y= mx+c)
        
        return a
        
    def loss_BC(self,x,y):
        # Boundary condition loss 
        # Splitting the forward pass and loss computation to visualise the pointwise loss
        forwarded_BC = self.forward(x)
        loss_u = self.loss_function(forwarded_BC,y)
                
        return loss_u

    def loss_PDE(self, x_to_train_f):
        
        #nu = 0.01/np.pi
        #k = 0.01  # thermal conductivity
        #
        # 3D heat conduction with constant k and no heat generation term
        # We don't need k
        # T_xx + T_yy + T_zz = 0
        # This is also known as the Laplace equation
        
        x_1_f = x_to_train_f[:,[0]]
        x_2_f = x_to_train_f[:,[1]]
                        
        g = x_to_train_f.clone()
                        
        g.requires_grad = True
        
        u = self.forward(g)
                
        #u_x_t = autograd.grad(u,g,torch.ones([x_to_train_f.shape[0], 1]).to(device), retain_graph=True, create_graph=True)[0]
                                
        #u_xx_tt = autograd.grad(u_x_t,g,torch.ones(x_to_train_f.shape).to(device), create_graph=True)[0]
                                                            
        #u_x = u_x_t[:,[0]]
        
        #u_t = u_x_t[:,[1]]
        
        #u_xx = u_xx_tt[:,[0]]
        # This is 2D problem
        # First derivative of u w.r.t to all inputs i.e. x, y and z
        u_x_y = autograd.grad(u,g,torch.ones([x_to_train_f.shape[0], 1]).to(device), retain_graph=True, create_graph=True)[0]
        # Second derivative of u w.r.t to all inputs i.e. x, y and z                        
        u_xx_yy = autograd.grad(u_x_y,g,torch.ones(x_to_train_f.shape).to(device), create_graph=True)[0]
        # Since there are 3 input vectors x,y and z                                                    
        u_xx = u_xx_yy[:,[0]]
        
        u_yy = u_xx_yy[:,[1]]
        
        u_zz = u_xx_yy[:,[2]]
                                        
        #f = u_t + (self.forward(g))*(u_x) - (nu)*u_xx 
        
        #loss_f = self.loss_function(f,f_hat)
        # PDE loss                                
        f = u_xx + u_yy + u_zz # PDE remians the same
        
        loss_f = self.loss_function(f,f_hat) # f_hat is global variable in the main section
                
        return loss_f
    
    def loss(self,x,y,x_to_train_f):

        loss_u = self.loss_BC(x,y)
        loss_f = self.loss_PDE(x_to_train_f)
        
        loss_val = loss_u + loss_f
        
        return loss_val
     
    'callable for optimizer'                                       
    def closure(self):
        
        optimizer.zero_grad()
        
        loss = self.loss(X_u_train, u_train, X_f_train)
        
        loss.backward()
                
        self.iter += 1
        
        if self.iter % 100 == 0:

            error_vec, _ = PINN.test()
        
            print(loss,error_vec)

        return loss        
    
    'test neural network'
    def test(self):
        # we don't have true solution (u) to play with            
        u_pred = self.forward(X_u_test_tensor)
        
        #error_vec = torch.linalg.norm((u-u_pred),2)/torch.linalg.norm(u,2)        # Relative L2 Norm of the error (Vector)
        
        u_pred = u_pred.cpu().detach().numpy()
        
        #u_pred = np.reshape(u_pred,(256,100),order='F')
                
        return u_pred#, error_vec

# %% [markdown]
# # Main

# %%
 
N_u = 100 #Total number of data points for 'u'
N_f = 10_000 #Total number of collocation points 
X_f_train_np_array, X_u_train_np_array, u_train_np_array = trainingdata(N_u,N_f)

# Convert numpy arrays to tensors 
X_f_train = torch.from_numpy(X_f_train_np_array).float().to(device)
X_u_train = torch.from_numpy(X_u_train_np_array).float().to(device)
u_train = torch.from_numpy(u_train_np_array).float().to(device)
X_u_test_tensor = torch.from_numpy(X_u_test).float().to(device)
# u = torch.from_numpy(u_true).float().to(device) no true solution
f_hat = torch.zeros(X_f_train.shape[0],1).to(device)

layers = np.array([3,1024,1024,1024,1024,1]) # Units in hidden layers
#layers = np.array([3,50,50,50,50,1]) 
#layers = np.array([3,100,100,100,100,1]) 

PINN = Sequentialmodel(layers)
bestPINN = Sequentialmodel(layers) # this is our model with lowest training because PINNs don't have validation but testing error
# We do not need to assign this to a device as we will not train the bestPINN model.
PINN.to(device) # last iteration PINN
bestPINN.to(device) # best PINN on the basis of the training loss

params = list(PINN.parameters())

# Optimisation
# L-BFGS Optimiser
# optimizer = torch.optim.LBFGS(PINN.parameters(), lr=0.1, 
#                               max_iter = 5000, 
#                               max_eval = None, 
#                               tolerance_grad = 1e-05, 
#                               tolerance_change = 1e-09, 
#                               history_size = 100, 
#                               line_search_fn = 'strong_wolfe')

# start_time = time.time()

# optimizer.step(PINN.closure)

# Adam optimiser
optimizer = optim.Adam(PINN.parameters(), lr=0.001,betas=(0.9, 0.999), eps=1e-08, weight_decay=0, amsgrad=False)
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=4000, gamma=0.95) # LR scheduler


max_iter = 30000

start_time = time.time()
BC_loss_array = np.zeros(max_iter)
PDE_loss_array = np.zeros(max_iter)
total_loss_array = np.zeros(max_iter)
#test_error_array = np.zeros(max_iter)
#flag = np.zeros(max_iter,dtype=bool)

for i in range(max_iter):
    BC_loss =  PINN.loss_BC(X_u_train, u_train) # BC loss
    PDE_loss = PINN.loss_PDE(X_f_train) # PDE loss

    total_loss = BC_loss + PDE_loss #PINN.loss(BC_loss, PDE_loss, X_f_train)
           
    optimizer.zero_grad()     # zeroes the gradient in each epoch
    
    total_loss.backward() # backprop the total loss and store in .grad()
    optimizer.step()  # update parameters
    scheduler.step()
    
    #error_vec, _ = PINN.test() # save time by not predicting the u_pred in each iteration
    BC_loss_array [i] = BC_loss
    PDE_loss_array[i] = PDE_loss
    total_loss_array[i] = total_loss  
    #test_error_array[i] = error_vec
    
    # printing losses
    if i % (max_iter/100) == 0:
        print(f" Epoch: {i+1} \t BC Loss: {BC_loss:0.4f}\t PDE Loss: {PDE_loss:0.4f} \t Loss: {total_loss:0.4f}")#" \t Test Error: {error_vec:0.4f}")
    if total_loss < 1e-6:
        print(f'Loss converged in {i} Epochs')
        break
        
    # Choosing the best model using the total loss not validation loss
    
    #if i>=2 and test_error_array[i] < np.amin(test_error_array[0:(i-1)]): # if current total loss is the minimum in the test loss array for all previous iterations i.e. [0,i-1]
    if i>=2 and total_loss_array[i] < np.amin(total_loss_array[0:(i-1)]):
        # for i<2, in test_error_array[0:(i-1)] is i-1 is negative (i=0) and null (i=1), so better avoid first two iteration for selecting the best model
        #flag[i] = True
        print(f'Best model found at {i} th iteration with training loss = {total_loss_array[i]:0.4f}')
        bestPINN.load_state_dict(copy.deepcopy(PINN.state_dict())) # then the current PINN model is the best model, copying the state dictionary to the bestPINN
        # https://discuss.pytorch.org/t/copy-deepcopy-vs-clone/55022
        best_iter = i # save the best iteration to put it on the test error plot
    #else:
    #    flag[i]=False
#     if i % (max_iter/10) == 0:
#         error_vec, _ = PINN.test()
#         print(loss,error_vec)

else:
    print('Training finished')
    elapsed = time.time() - start_time                
    print('Training time(s): %.2f' % (elapsed))
    print(f"Final loss: {total_loss}")
# Out:
#  Epoch: 1 	 BC Loss: 0.3807	 PDE Loss: 0.0001 	 Loss: 0.3808
# Best model found at 2 th iteration with training loss = 0.3349
# Best model found at 4 th iteration with training loss = 0.2695
# Best model found at 16 th iteration with training loss = 0.2626
# Best model found at 21 th iteration with training loss = 0.2409
# Best model found at 22 th iteration with training loss = 0.2386
# Best model found at 27 th iteration with training loss = 0.2342
# Best model found at 28 th iteration with training loss = 0.2228
# Best model found at 42 th iteration with training loss = 0.2226
# Best model found at 49 th iteration with training loss = 0.2224
# Best model found at 57 th iteration with training loss = 0.2223
# Best model found at 64 th iteration with training loss = 0.2223
# Best model found at 65 th iteration with training loss = 0.2223
# Best model found at 72 th iteration with training loss = 0.2222
# Best model found at 73 th iteration with training loss = 0.2222
# Best model found at 79 th iteration with training loss = 0.2222
# Best model found at 80 th iteration with training loss = 0.2222
# Best model found at 81 th iteration with training loss = 0.2222
# Best model found at 87 th iteration with training loss = 0.2222
# Best model found at 88 th iteration with training loss = 0.2222
# Best model found at 94 th iteration with training loss = 0.2221
# Best model found at 95 th iteration with training loss = 0.2221
# Best model found at 96 th iteration with training loss = 0.2221
# Best model found at 101 th iteration with training loss = 0.2221
# Best model found at 102 th iteration with training loss = 0.2221
# Best model found at 103 th iteration with training loss = 0.2221
# Best model found at 107 th iteration with training loss = 0.2221
# Best model found at 108 th iteration with training loss = 0.2221
# Best model found at 109 th iteration with training loss = 0.2221
# Best model found at 110 th iteration with training loss = 0.2221
# Best model found at 111 th iteration with training loss = 0.2221
# Best model found at 112 th iteration with training loss = 0.2221
# Best model found at 113 th iteration with training loss = 0.2221
# Best model found at 114 th iteration with training loss = 0.2221
# Best model found at 115 th iteration with training loss = 0.2221
# Best model found at 116 th iteration with training loss = 0.2221
# Best model found at 117 th iteration with training loss = 0.2221
# Best model found at 118 th iteration with training loss = 0.2221
# Best model found at 119 th iteration with training loss = 0.2221
# Best model found at 120 th iteration with training loss = 0.2221
# Best model found at 121 th iteration with training loss = 0.2221
# Best model found at 122 th iteration with training loss = 0.2221
# Best model found at 123 th iteration with training loss = 0.2220
# Best model found at 124 th iteration with training loss = 0.2220
# Best model found at 125 th iteration with training loss = 0.2220
# Best model found at 126 th iteration with training loss = 0.2220
# Best model found at 127 th iteration with training loss = 0.2220
# Best model found at 128 th iteration with training loss = 0.2220
# Best model found at 129 th iteration with training loss = 0.2220
# Best model found at 130 th iteration with training loss = 0.2220
# Best model found at 131 th iteration with training loss = 0.2220
# Best model found at 132 th iteration with training loss = 0.2220
# Best model found at 133 th iteration with training loss = 0.2220
# Best model found at 134 th iteration with training loss = 0.2220
# Best model found at 135 th iteration with training loss = 0.2220
# Best model found at 136 th iteration with training loss = 0.2220
# Best model found at 137 th iteration with training loss = 0.2220
# Best model found at 138 th iteration with training loss = 0.2220
# Best model found at 139 th iteration with training loss = 0.2220
# Best model found at 140 th iteration with training loss = 0.2220
# Best model found at 141 th iteration with training loss = 0.2219
# Best model found at 142 th iteration with training loss = 0.2219
# Best model found at 143 th iteration with training loss = 0.2219
# Best model found at 144 th iteration with training loss = 0.2219
# Best model found at 145 th iteration with training loss = 0.2219
# Best model found at 146 th iteration with training loss = 0.2219
# Best model found at 147 th iteration with training loss = 0.2219
# Best model found at 148 th iteration with training loss = 0.2219
# Best model found at 149 th iteration with training loss = 0.2219
# Best model found at 150 th iteration with training loss = 0.2219
# Best model found at 151 th iteration with training loss = 0.2218
# Best model found at 152 th iteration with training loss = 0.2218
# Best model found at 153 th iteration with training loss = 0.2218
# Best model found at 154 th iteration with training loss = 0.2218
# Best model found at 155 th iteration with training loss = 0.2218
# Best model found at 156 th iteration with training loss = 0.2218
# Best model found at 157 th iteration with training loss = 0.2218
# Best model found at 158 th iteration with training loss = 0.2217
# Best model found at 159 th iteration with training loss = 0.2217
# Best model found at 160 th iteration with training loss = 0.2217
# Best model found at 161 th iteration with training loss = 0.2217
# Best model found at 162 th iteration with training loss = 0.2217
# Best model found at 163 th iteration with training loss = 0.2216
# Best model found at 164 th iteration with training loss = 0.2216
# Best model found at 165 th iteration with training loss = 0.2216
# Best model found at 166 th iteration with training loss = 0.2215
# Best model found at 167 th iteration with training loss = 0.2215
# Best model found at 168 th iteration with training loss = 0.2215
# Best model found at 169 th iteration with training loss = 0.2214
# Best model found at 170 th iteration with training loss = 0.2214
# Best model found at 171 th iteration with training loss = 0.2214
# Best model found at 172 th iteration with training loss = 0.2213
# Best model found at 173 th iteration with training loss = 0.2212
# Best model found at 174 th iteration with training loss = 0.2212
# Best model found at 175 th iteration with training loss = 0.2211
# Best model found at 176 th iteration with training loss = 0.2211
# Best model found at 177 th iteration with training loss = 0.2210
# Best model found at 178 th iteration with training loss = 0.2209
# Best model found at 179 th iteration with training loss = 0.2208
# Best model found at 180 th iteration with training loss = 0.2207
# Best model found at 181 th iteration with training loss = 0.2206
# Best model found at 182 th iteration with training loss = 0.2204
# Best model found at 183 th iteration with training loss = 0.2203
# Best model found at 184 th iteration with training loss = 0.2201
# Best model found at 185 th iteration with training loss = 0.2200
# Best model found at 186 th iteration with training loss = 0.2198
# Best model found at 187 th iteration with training loss = 0.2195
# Best model found at 188 th iteration with training loss = 0.2193
# Best model found at 189 th iteration with training loss = 0.2190
# Best model found at 190 th iteration with training loss = 0.2187
# Best model found at 191 th iteration with training loss = 0.2184
# Best model found at 192 th iteration with training loss = 0.2180
# Best model found at 193 th iteration with training loss = 0.2175
# Best model found at 194 th iteration with training loss = 0.2171
# Best model found at 195 th iteration with training loss = 0.2165
# Best model found at 196 th iteration with training loss = 0.2160
# Best model found at 197 th iteration with training loss = 0.2153
# Best model found at 198 th iteration with training loss = 0.2146
# Best model found at 199 th iteration with training loss = 0.2139
# Best model found at 200 th iteration with training loss = 0.2131
# Best model found at 201 th iteration with training loss = 0.2122
# Best model found at 202 th iteration with training loss = 0.2113
# Best model found at 203 th iteration with training loss = 0.2103
# Best model found at 204 th iteration with training loss = 0.2093
# Best model found at 205 th iteration with training loss = 0.2082
# Best model found at 206 th iteration with training loss = 0.2071
# Best model found at 207 th iteration with training loss = 0.2060
# Best model found at 208 th iteration with training loss = 0.2049
# Best model found at 209 th iteration with training loss = 0.2037
# Best model found at 210 th iteration with training loss = 0.2026
# Best model found at 211 th iteration with training loss = 0.2015
# Best model found at 212 th iteration with training loss = 0.2005
# Best model found at 213 th iteration with training loss = 0.1995
# Best model found at 214 th iteration with training loss = 0.1985
# Best model found at 215 th iteration with training loss = 0.1976
# Best model found at 216 th iteration with training loss = 0.1969
# Best model found at 217 th iteration with training loss = 0.1962
# Best model found at 218 th iteration with training loss = 0.1956
# Best model found at 219 th iteration with training loss = 0.1951
# Best model found at 220 th iteration with training loss = 0.1947
# Best model found at 221 th iteration with training loss = 0.1944
# Best model found at 222 th iteration with training loss = 0.1941
# Best model found at 223 th iteration with training loss = 0.1940
# Best model found at 224 th iteration with training loss = 0.1939
# Best model found at 225 th iteration with training loss = 0.1939
# Best model found at 226 th iteration with training loss = 0.1939
# Best model found at 235 th iteration with training loss = 0.1938
# Best model found at 236 th iteration with training loss = 0.1937
# Best model found at 237 th iteration with training loss = 0.1936
# Best model found at 238 th iteration with training loss = 0.1935
# Best model found at 239 th iteration with training loss = 0.1934
# Best model found at 240 th iteration with training loss = 0.1933
# Best model found at 241 th iteration with training loss = 0.1932
# Best model found at 242 th iteration with training loss = 0.1931
# Best model found at 243 th iteration with training loss = 0.1930
# Best model found at 244 th iteration with training loss = 0.1929
# Best model found at 245 th iteration with training loss = 0.1929
# Best model found at 246 th iteration with training loss = 0.1928
# Best model found at 247 th iteration with training loss = 0.1928
# Best model found at 248 th iteration with training loss = 0.1927
# Best model found at 249 th iteration with training loss = 0.1927
# Best model found at 250 th iteration with training loss = 0.1926
# Best model found at 251 th iteration with training loss = 0.1926
# Best model found at 252 th iteration with training loss = 0.1926
# Best model found at 253 th iteration with training loss = 0.1925
# Best model found at 254 th iteration with training loss = 0.1925
# Best model found at 255 th iteration with training loss = 0.1925
# Best model found at 256 th iteration with training loss = 0.1924
# Best model found at 257 th iteration with training loss = 0.1924
# Best model found at 258 th iteration with training loss = 0.1923
# Best model found at 259 th iteration with training loss = 0.1923
# Best model found at 260 th iteration with training loss = 0.1922
# Best model found at 261 th iteration with training loss = 0.1922
# Best model found at 262 th iteration with training loss = 0.1921
# Best model found at 263 th iteration with training loss = 0.1921
# Best model found at 264 th iteration with training loss = 0.1920
# Best model found at 265 th iteration with training loss = 0.1920
# Best model found at 266 th iteration with training loss = 0.1919
# Best model found at 267 th iteration with training loss = 0.1918
# Best model found at 268 th iteration with training loss = 0.1918
# Best model found at 269 th iteration with training loss = 0.1917
# Best model found at 270 th iteration with training loss = 0.1917
# Best model found at 271 th iteration with training loss = 0.1916
# Best model found at 272 th iteration with training loss = 0.1916
# Best model found at 273 th iteration with training loss = 0.1915
# Best model found at 274 th iteration with training loss = 0.1915
# Best model found at 275 th iteration with training loss = 0.1914
# Best model found at 276 th iteration with training loss = 0.1913
# Best model found at 277 th iteration with training loss = 0.1913
# Best model found at 278 th iteration with training loss = 0.1912
# Best model found at 279 th iteration with training loss = 0.1911
# Best model found at 280 th iteration with training loss = 0.1910
# Best model found at 281 th iteration with training loss = 0.1910
# Best model found at 282 th iteration with training loss = 0.1909
# Best model found at 283 th iteration with training loss = 0.1908
# Best model found at 284 th iteration with training loss = 0.1907
# Best model found at 285 th iteration with training loss = 0.1906
# Best model found at 286 th iteration with training loss = 0.1905
# Best model found at 287 th iteration with training loss = 0.1905
# Best model found at 288 th iteration with training loss = 0.1904
# Best model found at 289 th iteration with training loss = 0.1903
# Best model found at 290 th iteration with training loss = 0.1901
# Best model found at 291 th iteration with training loss = 0.1900
# Best model found at 292 th iteration with training loss = 0.1899
# Best model found at 293 th iteration with training loss = 0.1898
# Best model found at 294 th iteration with training loss = 0.1897
# Best model found at 295 th iteration with training loss = 0.1895
# Best model found at 296 th iteration with training loss = 0.1894
# Best model found at 297 th iteration with training loss = 0.1893
# Best model found at 298 th iteration with training loss = 0.1891
# Best model found at 299 th iteration with training loss = 0.1890
#  Epoch: 301 	 BC Loss: 0.1864	 PDE Loss: 0.0024 	 Loss: 0.1888
# Best model found at 300 th iteration with training loss = 0.1888
# Best model found at 301 th iteration with training loss = 0.1886
# Best model found at 302 th iteration with training loss = 0.1884
# Best model found at 303 th iteration with training loss = 0.1883
# Best model found at 304 th iteration with training loss = 0.1881
# Best model found at 305 th iteration with training loss = 0.1878
# Best model found at 306 th iteration with training loss = 0.1876
# Best model found at 307 th iteration with training loss = 0.1874
# Best model found at 308 th iteration with training loss = 0.1871
# Best model found at 309 th iteration with training loss = 0.1869
# Best model found at 310 th iteration with training loss = 0.1866
# Best model found at 311 th iteration with training loss = 0.1863
# Best model found at 312 th iteration with training loss = 0.1860
# Best model found at 313 th iteration with training loss = 0.1857
# Best model found at 314 th iteration with training loss = 0.1853
# Best model found at 315 th iteration with training loss = 0.1850
# Best model found at 316 th iteration with training loss = 0.1846
# Best model found at 317 th iteration with training loss = 0.1842
# Best model found at 318 th iteration with training loss = 0.1837
# Best model found at 319 th iteration with training loss = 0.1832
# Best model found at 320 th iteration with training loss = 0.1827
# Best model found at 321 th iteration with training loss = 0.1822
# Best model found at 322 th iteration with training loss = 0.1816
# Best model found at 323 th iteration with training loss = 0.1810
# Best model found at 324 th iteration with training loss = 0.1803
# Best model found at 325 th iteration with training loss = 0.1796
# Best model found at 326 th iteration with training loss = 0.1788
# Best model found at 327 th iteration with training loss = 0.1780
# Best model found at 328 th iteration with training loss = 0.1772
# Best model found at 329 th iteration with training loss = 0.1763
# Best model found at 330 th iteration with training loss = 0.1754
# Best model found at 331 th iteration with training loss = 0.1744
# Best model found at 332 th iteration with training loss = 0.1735
# Best model found at 333 th iteration with training loss = 0.1725
# Best model found at 334 th iteration with training loss = 0.1716
# Best model found at 335 th iteration with training loss = 0.1707
# Best model found at 336 th iteration with training loss = 0.1697
# Best model found at 337 th iteration with training loss = 0.1688
# Best model found at 338 th iteration with training loss = 0.1679
# Best model found at 339 th iteration with training loss = 0.1671
# Best model found at 340 th iteration with training loss = 0.1663
# Best model found at 341 th iteration with training loss = 0.1654
# Best model found at 342 th iteration with training loss = 0.1645
# Best model found at 343 th iteration with training loss = 0.1636
# Best model found at 344 th iteration with training loss = 0.1627
# Best model found at 345 th iteration with training loss = 0.1622
# Best model found at 459 th iteration with training loss = 0.1622
# Best model found at 460 th iteration with training loss = 0.1613
# Best model found at 461 th iteration with training loss = 0.1605
# Best model found at 462 th iteration with training loss = 0.1596
# Best model found at 463 th iteration with training loss = 0.1588
# Best model found at 464 th iteration with training loss = 0.1581
# Best model found at 465 th iteration with training loss = 0.1573
# Best model found at 466 th iteration with training loss = 0.1565
# Best model found at 467 th iteration with training loss = 0.1558
# Best model found at 468 th iteration with training loss = 0.1550
# Best model found at 469 th iteration with training loss = 0.1542
# Best model found at 470 th iteration with training loss = 0.1535
# Best model found at 471 th iteration with training loss = 0.1527
# Best model found at 472 th iteration with training loss = 0.1521
# Best model found at 473 th iteration with training loss = 0.1521
# Best model found at 515 th iteration with training loss = 0.1519
# Best model found at 516 th iteration with training loss = 0.1485
# Best model found at 517 th iteration with training loss = 0.1477
# Best model found at 518 th iteration with training loss = 0.1457
# Best model found at 519 th iteration with training loss = 0.1439
# Best model found at 520 th iteration with training loss = 0.1427
# Best model found at 521 th iteration with training loss = 0.1410
# Best model found at 522 th iteration with training loss = 0.1400
# Best model found at 523 th iteration with training loss = 0.1387
# Best model found at 524 th iteration with training loss = 0.1384
# Best model found at 525 th iteration with training loss = 0.1365
# Best model found at 526 th iteration with training loss = 0.1370
# Best model found at 527 th iteration with training loss = 0.1362
# Best model found at 528 th iteration with training loss = 0.1361
# Best model found at 561 th iteration with training loss = 0.1347
# Best model found at 562 th iteration with training loss = 0.1330
# Best model found at 563 th iteration with training loss = 0.1292
# Best model found at 564 th iteration with training loss = 0.1289
# Best model found at 565 th iteration with training loss = 0.1266
# Best model found at 566 th iteration with training loss = 0.1258
# Best model found at 567 th iteration with training loss = 0.1215
# Best model found at 568 th iteration with training loss = 0.1225
#  Epoch: 601 	 BC Loss: 0.1329	 PDE Loss: 0.0027 	 Loss: 0.1356
# Best model found at 606 th iteration with training loss = 0.1213
# Best model found at 607 th iteration with training loss = 0.1188
# Best model found at 608 th iteration with training loss = 0.1163
# Best model found at 609 th iteration with training loss = 0.1178
# Best model found at 610 th iteration with training loss = 0.1127
# Best model found at 611 th iteration with training loss = 0.1135
# Best model found at 613 th iteration with training loss = 0.1109
# Best model found at 660 th iteration with training loss = 0.1109
# Best model found at 661 th iteration with training loss = 0.1094
# Best model found at 662 th iteration with training loss = 0.1085
# Best model found at 663 th iteration with training loss = 0.1058
# Best model found at 664 th iteration with training loss = 0.1062
# Best model found at 665 th iteration with training loss = 0.1045
# Best model found at 666 th iteration with training loss = 0.1022
# Best model found at 667 th iteration with training loss = 0.1022
# Best model found at 668 th iteration with training loss = 0.1021
# Best model found at 669 th iteration with training loss = 0.1006
# Best model found at 670 th iteration with training loss = 0.0990
# Best model found at 671 th iteration with training loss = 0.0988
# Best model found at 672 th iteration with training loss = 0.0989
# Best model found at 673 th iteration with training loss = 0.0987
# Best model found at 674 th iteration with training loss = 0.0978
# Best model found at 675 th iteration with training loss = 0.0966
# Best model found at 676 th iteration with training loss = 0.0952
# Best model found at 677 th iteration with training loss = 0.0942
# Best model found at 678 th iteration with training loss = 0.0932
# Best model found at 679 th iteration with training loss = 0.0925
# Best model found at 680 th iteration with training loss = 0.0920
# Best model found at 681 th iteration with training loss = 0.0916
# Best model found at 682 th iteration with training loss = 0.0915
# Best model found at 715 th iteration with training loss = 0.0902
# Best model found at 719 th iteration with training loss = 0.0877
# Best model found at 720 th iteration with training loss = 0.0875
# Best model found at 747 th iteration with training loss = 0.0867
# Best model found at 750 th iteration with training loss = 0.0835
# Best model found at 753 th iteration with training loss = 0.0820
# Best model found at 754 th iteration with training loss = 0.0810
# Best model found at 757 th iteration with training loss = 0.0789
# Best model found at 758 th iteration with training loss = 0.0800
# Best model found at 761 th iteration with training loss = 0.0778
# Best model found at 762 th iteration with training loss = 0.0789
# Best model found at 828 th iteration with training loss = 0.0774
# Best model found at 829 th iteration with training loss = 0.0766
# Best model found at 830 th iteration with training loss = 0.0763
# Best model found at 831 th iteration with training loss = 0.0761
# Best model found at 832 th iteration with training loss = 0.0758
# Best model found at 833 th iteration with training loss = 0.0755
# Best model found at 834 th iteration with training loss = 0.0749
# Best model found at 835 th iteration with training loss = 0.0746
# Best model found at 836 th iteration with training loss = 0.0743
# Best model found at 837 th iteration with training loss = 0.0740
# Best model found at 838 th iteration with training loss = 0.0739
# Best model found at 839 th iteration with training loss = 0.0736
# Best model found at 840 th iteration with training loss = 0.0734
# Best model found at 841 th iteration with training loss = 0.0732
# Best model found at 842 th iteration with training loss = 0.0730
# Best model found at 843 th iteration with training loss = 0.0731
# Best model found at 892 th iteration with training loss = 0.0715
# Best model found at 893 th iteration with training loss = 0.0722
# Best model found at 894 th iteration with training loss = 0.0713
# Best model found at 895 th iteration with training loss = 0.0700
# Best model found at 896 th iteration with training loss = 0.0706
# Best model found at 898 th iteration with training loss = 0.0694
# Best model found at 899 th iteration with training loss = 0.0694
#  Epoch: 901 	 BC Loss: 0.0674	 PDE Loss: 0.0024 	 Loss: 0.0698
# Best model found at 901 th iteration with training loss = 0.0692
# Best model found at 902 th iteration with training loss = 0.0684
# Best model found at 903 th iteration with training loss = 0.0685
# Best model found at 906 th iteration with training loss = 0.0681
# Best model found at 907 th iteration with training loss = 0.0679
# Best model found at 908 th iteration with training loss = 0.0679
# Best model found at 909 th iteration with training loss = 0.0678
# Best model found at 910 th iteration with training loss = 0.0675
# Best model found at 911 th iteration with training loss = 0.0673
# Best model found at 912 th iteration with training loss = 0.0671
# Best model found at 913 th iteration with training loss = 0.0671
# Best model found at 980 th iteration with training loss = 0.0670
# Best model found at 981 th iteration with training loss = 0.0669
# Best model found at 982 th iteration with training loss = 0.0667
# Best model found at 983 th iteration with training loss = 0.0668
# Best model found at 1034 th iteration with training loss = 0.0666
# Best model found at 1036 th iteration with training loss = 0.0664
# Best model found at 1038 th iteration with training loss = 0.0663
# Best model found at 1039 th iteration with training loss = 0.0663
# Best model found at 1040 th iteration with training loss = 0.0661
# Best model found at 1041 th iteration with training loss = 0.0659
# Best model found at 1042 th iteration with training loss = 0.0654
# Best model found at 1043 th iteration with training loss = 0.0655
# Best model found at 1044 th iteration with training loss = 0.0650
# Best model found at 1045 th iteration with training loss = 0.0649
# Best model found at 1046 th iteration with training loss = 0.0648
# Best model found at 1047 th iteration with training loss = 0.0647
# Best model found at 1048 th iteration with training loss = 0.0644
# Best model found at 1049 th iteration with training loss = 0.0645
# Best model found at 1050 th iteration with training loss = 0.0642
# Best model found at 1051 th iteration with training loss = 0.0642
# Best model found at 1052 th iteration with training loss = 0.0641
# Best model found at 1053 th iteration with training loss = 0.0639
# Best model found at 1054 th iteration with training loss = 0.0638
# Best model found at 1055 th iteration with training loss = 0.0638
# Best model found at 1056 th iteration with training loss = 0.0636
# Best model found at 1057 th iteration with training loss = 0.0635
# Best model found at 1058 th iteration with training loss = 0.0634
# Best model found at 1059 th iteration with training loss = 0.0633
# Best model found at 1060 th iteration with training loss = 0.0632
# Best model found at 1061 th iteration with training loss = 0.0631
# Best model found at 1062 th iteration with training loss = 0.0631
# Best model found at 1063 th iteration with training loss = 0.0630
# Best model found at 1064 th iteration with training loss = 0.0628
# Best model found at 1065 th iteration with training loss = 0.0628
# Best model found at 1066 th iteration with training loss = 0.0627
# Best model found at 1067 th iteration with training loss = 0.0627
# Best model found at 1068 th iteration with training loss = 0.0626
# Best model found at 1069 th iteration with training loss = 0.0625
# Best model found at 1070 th iteration with training loss = 0.0625
# Best model found at 1071 th iteration with training loss = 0.0624
# Best model found at 1072 th iteration with training loss = 0.0623
# Best model found at 1073 th iteration with training loss = 0.0623
# Best model found at 1074 th iteration with training loss = 0.0622
# Best model found at 1075 th iteration with training loss = 0.0621
# Best model found at 1076 th iteration with training loss = 0.0621
# Best model found at 1077 th iteration with training loss = 0.0620
# Best model found at 1078 th iteration with training loss = 0.0620
# Best model found at 1079 th iteration with training loss = 0.0620
# Best model found at 1125 th iteration with training loss = 0.0619
# Best model found at 1131 th iteration with training loss = 0.0618
# Best model found at 1132 th iteration with training loss = 0.0613
# Best model found at 1133 th iteration with training loss = 0.0615
# Best model found at 1137 th iteration with training loss = 0.0613
# Best model found at 1138 th iteration with training loss = 0.0612
# Best model found at 1139 th iteration with training loss = 0.0611
# Best model found at 1140 th iteration with training loss = 0.0609
# Best model found at 1141 th iteration with training loss = 0.0607
# Best model found at 1142 th iteration with training loss = 0.0608
# Best model found at 1184 th iteration with training loss = 0.0602
#  Epoch: 1201 	 BC Loss: 0.0617	 PDE Loss: 0.0007 	 Loss: 0.0624
# Best model found at 1210 th iteration with training loss = 0.0599
# Best model found at 1232 th iteration with training loss = 0.0597
# Best model found at 1238 th iteration with training loss = 0.0596
# Best model found at 1239 th iteration with training loss = 0.0589
# Best model found at 1324 th iteration with training loss = 0.0585
# Best model found at 1331 th iteration with training loss = 0.0584
# Best model found at 1332 th iteration with training loss = 0.0583
# Best model found at 1335 th iteration with training loss = 0.0581
# Best model found at 1336 th iteration with training loss = 0.0581
# Best model found at 1337 th iteration with training loss = 0.0581
# Best model found at 1338 th iteration with training loss = 0.0579
# Best model found at 1339 th iteration with training loss = 0.0579
# Best model found at 1342 th iteration with training loss = 0.0577
# Best model found at 1343 th iteration with training loss = 0.0576
# Best model found at 1472 th iteration with training loss = 0.0576
# Best model found at 1473 th iteration with training loss = 0.0575
# Best model found at 1474 th iteration with training loss = 0.0575
# Best model found at 1475 th iteration with training loss = 0.0574
# Best model found at 1476 th iteration with training loss = 0.0573
# Best model found at 1477 th iteration with training loss = 0.0573
# Best model found at 1478 th iteration with training loss = 0.0572
# Best model found at 1479 th iteration with training loss = 0.0572
# Best model found at 1480 th iteration with training loss = 0.0571
# Best model found at 1481 th iteration with training loss = 0.0570
# Best model found at 1482 th iteration with training loss = 0.0570
# Best model found at 1483 th iteration with training loss = 0.0569
# Best model found at 1484 th iteration with training loss = 0.0569
# Best model found at 1485 th iteration with training loss = 0.0569
# Best model found at 1486 th iteration with training loss = 0.0568
# Best model found at 1487 th iteration with training loss = 0.0568
# Best model found at 1488 th iteration with training loss = 0.0567
# Best model found at 1489 th iteration with training loss = 0.0567
#  Epoch: 1501 	 BC Loss: 0.0723	 PDE Loss: 0.0027 	 Loss: 0.0750
# Best model found at 1527 th iteration with training loss = 0.0564
# Best model found at 1528 th iteration with training loss = 0.0563
# Best model found at 1533 th iteration with training loss = 0.0562
# Best model found at 1534 th iteration with training loss = 0.0561
# Best model found at 1535 th iteration with training loss = 0.0562
# Best model found at 1597 th iteration with training loss = 0.0560
# Best model found at 1598 th iteration with training loss = 0.0554
# Best model found at 1653 th iteration with training loss = 0.0552
# Best model found at 1725 th iteration with training loss = 0.0551
# Best model found at 1726 th iteration with training loss = 0.0544
# Best model found at 1727 th iteration with training loss = 0.0544
# Best model found at 1728 th iteration with training loss = 0.0543
# Best model found at 1729 th iteration with training loss = 0.0542
# Best model found at 1788 th iteration with training loss = 0.0542
# Best model found at 1791 th iteration with training loss = 0.0541
# Best model found at 1792 th iteration with training loss = 0.0537
#  Epoch: 1801 	 BC Loss: 0.0529	 PDE Loss: 0.0111 	 Loss: 0.0640
# Best model found at 1822 th iteration with training loss = 0.0533
# Best model found at 1823 th iteration with training loss = 0.0533
# Best model found at 1836 th iteration with training loss = 0.0528
# Best model found at 1837 th iteration with training loss = 0.0522
# Best model found at 1838 th iteration with training loss = 0.0520
# Best model found at 1839 th iteration with training loss = 0.0521
# Best model found at 1935 th iteration with training loss = 0.0519
# Best model found at 1942 th iteration with training loss = 0.0516
# Best model found at 1943 th iteration with training loss = 0.0506
# Best model found at 1944 th iteration with training loss = 0.0508
# Best model found at 2035 th iteration with training loss = 0.0506
# Best model found at 2039 th iteration with training loss = 0.0501
# Best model found at 2040 th iteration with training loss = 0.0501
#  Epoch: 2101 	 BC Loss: 0.0583	 PDE Loss: 0.0053 	 Loss: 0.0636
# Best model found at 2295 th iteration with training loss = 0.0493
# Best model found at 2296 th iteration with training loss = 0.0493
# Best model found at 2300 th iteration with training loss = 0.0488
# Best model found at 2301 th iteration with training loss = 0.0491
# Best model found at 2304 th iteration with training loss = 0.0488
# Best model found at 2305 th iteration with training loss = 0.0484
# Best model found at 2306 th iteration with training loss = 0.0482
# Best model found at 2342 th iteration with training loss = 0.0481
# Best model found at 2347 th iteration with training loss = 0.0471
# Best model found at 2348 th iteration with training loss = 0.0468
#  Epoch: 2401 	 BC Loss: 0.0623	 PDE Loss: 0.0069 	 Loss: 0.0692
#  Epoch: 2701 	 BC Loss: 0.0468	 PDE Loss: 0.0092 	 Loss: 0.0560
# Best model found at 2727 th iteration with training loss = 0.0454
# Best model found at 2728 th iteration with training loss = 0.0463
# Best model found at 2786 th iteration with training loss = 0.0454
# Best model found at 2789 th iteration with training loss = 0.0448
# Best model found at 2790 th iteration with training loss = 0.0440
#  Epoch: 3001 	 BC Loss: 0.1346	 PDE Loss: 0.0045 	 Loss: 0.1392
#  Epoch: 3301 	 BC Loss: 0.0511	 PDE Loss: 0.0029 	 Loss: 0.0540
#  Epoch: 3601 	 BC Loss: 0.0468	 PDE Loss: 0.0021 	 Loss: 0.0489
#  Epoch: 3901 	 BC Loss: 0.0487	 PDE Loss: 0.0014 	 Loss: 0.0501
# Best model found at 4018 th iteration with training loss = 0.0436
# Best model found at 4019 th iteration with training loss = 0.0430
# Best model found at 4020 th iteration with training loss = 0.0435
# Best model found at 4025 th iteration with training loss = 0.0425
# Best model found at 4026 th iteration with training loss = 0.0421
# Best model found at 4027 th iteration with training loss = 0.0420
#  Epoch: 4201 	 BC Loss: 0.0462	 PDE Loss: 0.0022 	 Loss: 0.0484
#  Epoch: 4501 	 BC Loss: 0.0513	 PDE Loss: 0.0053 	 Loss: 0.0566
# Best model found at 4549 th iteration with training loss = 0.0420
# Best model found at 4550 th iteration with training loss = 0.0420
# Best model found at 4766 th iteration with training loss = 0.0414
# Best model found at 4767 th iteration with training loss = 0.0409
# Best model found at 4768 th iteration with training loss = 0.0413
# Best model found at 4772 th iteration with training loss = 0.0408
# Best model found at 4773 th iteration with training loss = 0.0405
# Best model found at 4774 th iteration with training loss = 0.0404
# Best model found at 4775 th iteration with training loss = 0.0403
# Best model found at 4776 th iteration with training loss = 0.0401
# Best model found at 4777 th iteration with training loss = 0.0399
# Best model found at 4778 th iteration with training loss = 0.0398
#  Epoch: 4801 	 BC Loss: 0.0646	 PDE Loss: 0.0043 	 Loss: 0.0689
# Best model found at 4950 th iteration with training loss = 0.0397
# Best model found at 4951 th iteration with training loss = 0.0397
#  Epoch: 5101 	 BC Loss: 0.0627	 PDE Loss: 0.0045 	 Loss: 0.0672
# Best model found at 5155 th iteration with training loss = 0.0396
# Best model found at 5156 th iteration with training loss = 0.0395
# Best model found at 5157 th iteration with training loss = 0.0394
# Best model found at 5158 th iteration with training loss = 0.0393
# Best model found at 5159 th iteration with training loss = 0.0392
# Best model found at 5160 th iteration with training loss = 0.0391
# Best model found at 5161 th iteration with training loss = 0.0390
# Best model found at 5162 th iteration with training loss = 0.0389
# Best model found at 5163 th iteration with training loss = 0.0388
# Best model found at 5164 th iteration with training loss = 0.0387
# Best model found at 5165 th iteration with training loss = 0.0386
# Best model found at 5166 th iteration with training loss = 0.0385
# Best model found at 5167 th iteration with training loss = 0.0384
# Best model found at 5168 th iteration with training loss = 0.0383
# Best model found at 5169 th iteration with training loss = 0.0382
# Best model found at 5170 th iteration with training loss = 0.0382
# Best model found at 5171 th iteration with training loss = 0.0381
# Best model found at 5172 th iteration with training loss = 0.0380
# Best model found at 5173 th iteration with training loss = 0.0379
# Best model found at 5174 th iteration with training loss = 0.0378
# Best model found at 5175 th iteration with training loss = 0.0377
# Best model found at 5176 th iteration with training loss = 0.0377
# Best model found at 5177 th iteration with training loss = 0.0376
# Best model found at 5178 th iteration with training loss = 0.0375
# Best model found at 5179 th iteration with training loss = 0.0375
# Best model found at 5180 th iteration with training loss = 0.0375
# Best model found at 5250 th iteration with training loss = 0.0375
# Best model found at 5309 th iteration with training loss = 0.0371
# Best model found at 5310 th iteration with training loss = 0.0369
# Best model found at 5311 th iteration with training loss = 0.0367
# Best model found at 5314 th iteration with training loss = 0.0365
# Best model found at 5315 th iteration with training loss = 0.0362
# Best model found at 5316 th iteration with training loss = 0.0361
# Best model found at 5317 th iteration with training loss = 0.0361
# Best model found at 5320 th iteration with training loss = 0.0359
# Best model found at 5321 th iteration with training loss = 0.0358
# Best model found at 5322 th iteration with training loss = 0.0357
# Best model found at 5323 th iteration with training loss = 0.0356
# Best model found at 5324 th iteration with training loss = 0.0356
#  Epoch: 5401 	 BC Loss: 0.0511	 PDE Loss: 0.0039 	 Loss: 0.0550
#  Epoch: 5701 	 BC Loss: 0.0382	 PDE Loss: 0.0010 	 Loss: 0.0392
# Best model found at 5847 th iteration with training loss = 0.0355
# Best model found at 5848 th iteration with training loss = 0.0356
# Best model found at 5975 th iteration with training loss = 0.0351
# Best model found at 5976 th iteration with training loss = 0.0352
# Best model found at 5978 th iteration with training loss = 0.0349
# Best model found at 5979 th iteration with training loss = 0.0349
# Best model found at 5980 th iteration with training loss = 0.0348
# Best model found at 5981 th iteration with training loss = 0.0346
# Best model found at 5982 th iteration with training loss = 0.0345
# Best model found at 5983 th iteration with training loss = 0.0345
# Best model found at 5984 th iteration with training loss = 0.0345
# Best model found at 5986 th iteration with training loss = 0.0344
# Best model found at 5987 th iteration with training loss = 0.0343
# Best model found at 5988 th iteration with training loss = 0.0343
# Best model found at 5990 th iteration with training loss = 0.0343
#  Epoch: 6001 	 BC Loss: 0.0500	 PDE Loss: 0.0260 	 Loss: 0.0759
# Best model found at 6172 th iteration with training loss = 0.0339
# Best model found at 6173 th iteration with training loss = 0.0335
# Best model found at 6174 th iteration with training loss = 0.0336
#  Epoch: 6301 	 BC Loss: 0.0331	 PDE Loss: 0.0006 	 Loss: 0.0336
# Best model found at 6303 th iteration with training loss = 0.0335
# Best model found at 6304 th iteration with training loss = 0.0335
# Best model found at 6305 th iteration with training loss = 0.0333
# Best model found at 6306 th iteration with training loss = 0.0332
# Best model found at 6307 th iteration with training loss = 0.0331
# Best model found at 6308 th iteration with training loss = 0.0330
# Best model found at 6309 th iteration with training loss = 0.0330
# Best model found at 6310 th iteration with training loss = 0.0329
# Best model found at 6311 th iteration with training loss = 0.0328
# Best model found at 6312 th iteration with training loss = 0.0328
#  Epoch: 6601 	 BC Loss: 0.0413	 PDE Loss: 0.0011 	 Loss: 0.0423
#  Epoch: 6901 	 BC Loss: 0.0403	 PDE Loss: 0.0040 	 Loss: 0.0442
#  Epoch: 7201 	 BC Loss: 0.0731	 PDE Loss: 0.0190 	 Loss: 0.0921
# Best model found at 7499 th iteration with training loss = 0.0325
#  Epoch: 7501 	 BC Loss: 0.0319	 PDE Loss: 0.0008 	 Loss: 0.0326
# Best model found at 7500 th iteration with training loss = 0.0326
# Best model found at 7682 th iteration with training loss = 0.0324
# Best model found at 7683 th iteration with training loss = 0.0324
# Best model found at 7685 th iteration with training loss = 0.0324
# Best model found at 7686 th iteration with training loss = 0.0323
# Best model found at 7687 th iteration with training loss = 0.0323
# Best model found at 7688 th iteration with training loss = 0.0322
# Best model found at 7689 th iteration with training loss = 0.0322
# Best model found at 7759 th iteration with training loss = 0.0321
# Best model found at 7760 th iteration with training loss = 0.0321
# Best model found at 7762 th iteration with training loss = 0.0320
# Best model found at 7763 th iteration with training loss = 0.0319
#  Epoch: 7801 	 BC Loss: 0.0319	 PDE Loss: 0.0015 	 Loss: 0.0335
# Best model found at 7814 th iteration with training loss = 0.0318
# Best model found at 7815 th iteration with training loss = 0.0317
# Best model found at 7816 th iteration with training loss = 0.0317
# Best model found at 7817 th iteration with training loss = 0.0316
# Best model found at 7818 th iteration with training loss = 0.0316
# Best model found at 7819 th iteration with training loss = 0.0314
# Best model found at 7820 th iteration with training loss = 0.0313
# Best model found at 7821 th iteration with training loss = 0.0314
# Best model found at 7822 th iteration with training loss = 0.0313
# Best model found at 7823 th iteration with training loss = 0.0311
# Best model found at 7824 th iteration with training loss = 0.0311
# Best model found at 7826 th iteration with training loss = 0.0310
# Best model found at 7827 th iteration with training loss = 0.0309
# Best model found at 7828 th iteration with training loss = 0.0308
# Best model found at 7831 th iteration with training loss = 0.0308
# Best model found at 7832 th iteration with training loss = 0.0307
#  Epoch: 8101 	 BC Loss: 0.0602	 PDE Loss: 0.0039 	 Loss: 0.0641
# Best model found at 8207 th iteration with training loss = 0.0307
# Best model found at 8282 th iteration with training loss = 0.0298
# Best model found at 8283 th iteration with training loss = 0.0297
# Best model found at 8316 th iteration with training loss = 0.0297
# Best model found at 8317 th iteration with training loss = 0.0296
# Best model found at 8376 th iteration with training loss = 0.0294
#  Epoch: 8401 	 BC Loss: 0.0382	 PDE Loss: 0.0092 	 Loss: 0.0473
# Best model found at 8534 th iteration with training loss = 0.0294
# Best model found at 8535 th iteration with training loss = 0.0294
# Best model found at 8590 th iteration with training loss = 0.0292
# Best model found at 8591 th iteration with training loss = 0.0293
# Best model found at 8673 th iteration with training loss = 0.0288
#  Epoch: 8701 	 BC Loss: 0.0327	 PDE Loss: 0.0030 	 Loss: 0.0357
# Best model found at 8808 th iteration with training loss = 0.0287
# Best model found at 8809 th iteration with training loss = 0.0287
#  Epoch: 9001 	 BC Loss: 0.0302	 PDE Loss: 0.0006 	 Loss: 0.0308
#  Epoch: 9301 	 BC Loss: 0.0297	 PDE Loss: 0.0041 	 Loss: 0.0337
# Best model found at 9384 th iteration with training loss = 0.0286
# Best model found at 9388 th iteration with training loss = 0.0285
# Best model found at 9389 th iteration with training loss = 0.0285
# Best model found at 9495 th iteration with training loss = 0.0284
# Best model found at 9496 th iteration with training loss = 0.0284
# Best model found at 9550 th iteration with training loss = 0.0283
# Best model found at 9551 th iteration with training loss = 0.0282
# Best model found at 9552 th iteration with training loss = 0.0282
#  Epoch: 9601 	 BC Loss: 0.0392	 PDE Loss: 0.0042 	 Loss: 0.0434
# Best model found at 9779 th iteration with training loss = 0.0282
# Best model found at 9780 th iteration with training loss = 0.0280
# Best model found at 9781 th iteration with training loss = 0.0280
# Best model found at 9782 th iteration with training loss = 0.0280
# Best model found at 9783 th iteration with training loss = 0.0280
# Best model found at 9784 th iteration with training loss = 0.0279
# Best model found at 9852 th iteration with training loss = 0.0279
# Best model found at 9853 th iteration with training loss = 0.0279
# Best model found at 9854 th iteration with training loss = 0.0279
# Best model found at 9855 th iteration with training loss = 0.0278
# Best model found at 9856 th iteration with training loss = 0.0277
# Best model found at 9857 th iteration with training loss = 0.0277
# Best model found at 9858 th iteration with training loss = 0.0276
# Best model found at 9859 th iteration with training loss = 0.0276
# Best model found at 9860 th iteration with training loss = 0.0275
# Best model found at 9861 th iteration with training loss = 0.0275
# Best model found at 9862 th iteration with training loss = 0.0275
# Best model found at 9863 th iteration with training loss = 0.0274
# Best model found at 9864 th iteration with training loss = 0.0274
# Best model found at 9865 th iteration with training loss = 0.0274
# Best model found at 9866 th iteration with training loss = 0.0274
#  Epoch: 9901 	 BC Loss: 0.0348	 PDE Loss: 0.0019 	 Loss: 0.0367
#  Epoch: 10201 	 BC Loss: 0.0380	 PDE Loss: 0.0028 	 Loss: 0.0408
#  Epoch: 10501 	 BC Loss: 0.0294	 PDE Loss: 0.0009 	 Loss: 0.0303
#  Epoch: 10801 	 BC Loss: 0.0324	 PDE Loss: 0.0036 	 Loss: 0.0360
# Best model found at 10921 th iteration with training loss = 0.0273
# Best model found at 10922 th iteration with training loss = 0.0273
# Best model found at 11083 th iteration with training loss = 0.0270
# Best model found at 11084 th iteration with training loss = 0.0268
#  Epoch: 11101 	 BC Loss: 0.0342	 PDE Loss: 0.0077 	 Loss: 0.0419
# Best model found at 11200 th iteration with training loss = 0.0268
# Best model found at 11201 th iteration with training loss = 0.0268
# Best model found at 11334 th iteration with training loss = 0.0268
# Best model found at 11335 th iteration with training loss = 0.0267
#  Epoch: 11401 	 BC Loss: 0.0312	 PDE Loss: 0.0058 	 Loss: 0.0369
# Best model found at 11505 th iteration with training loss = 0.0266
# Best model found at 11508 th iteration with training loss = 0.0266
# Best model found at 11580 th iteration with training loss = 0.0265
# Best model found at 11583 th iteration with training loss = 0.0263
#  Epoch: 11701 	 BC Loss: 0.0341	 PDE Loss: 0.0048 	 Loss: 0.0389
# Best model found at 11818 th iteration with training loss = 0.0263
# Best model found at 11819 th iteration with training loss = 0.0261
# Best model found at 11820 th iteration with training loss = 0.0261
# Best model found at 11822 th iteration with training loss = 0.0261
# Best model found at 11823 th iteration with training loss = 0.0260
# Best model found at 11824 th iteration with training loss = 0.0260
#  Epoch: 12001 	 BC Loss: 0.0298	 PDE Loss: 0.0019 	 Loss: 0.0317
#  Epoch: 12301 	 BC Loss: 0.0294	 PDE Loss: 0.0008 	 Loss: 0.0302
#  Epoch: 12601 	 BC Loss: 0.0271	 PDE Loss: 0.0009 	 Loss: 0.0280
# Best model found at 12790 th iteration with training loss = 0.0259
# Best model found at 12791 th iteration with training loss = 0.0259
#  Epoch: 12901 	 BC Loss: 0.0318	 PDE Loss: 0.0639 	 Loss: 0.0957
#  Epoch: 13201 	 BC Loss: 0.0257	 PDE Loss: 0.0017 	 Loss: 0.0273
# Best model found at 13248 th iteration with training loss = 0.0259
# Best model found at 13249 th iteration with training loss = 0.0259
# Best model found at 13312 th iteration with training loss = 0.0256
# Best model found at 13443 th iteration with training loss = 0.0255
# Best model found at 13444 th iteration with training loss = 0.0255
# Best model found at 13446 th iteration with training loss = 0.0255
# Best model found at 13447 th iteration with training loss = 0.0255
#  Epoch: 13501 	 BC Loss: 0.0254	 PDE Loss: 0.0010 	 Loss: 0.0264
#  Epoch: 13801 	 BC Loss: 0.0265	 PDE Loss: 0.0011 	 Loss: 0.0276
# Best model found at 13880 th iteration with training loss = 0.0254
# Best model found at 13881 th iteration with training loss = 0.0253
# Best model found at 13882 th iteration with training loss = 0.0253
# Best model found at 13884 th iteration with training loss = 0.0253
# Best model found at 13885 th iteration with training loss = 0.0252
# Best model found at 13886 th iteration with training loss = 0.0252
# Best model found at 13948 th iteration with training loss = 0.0251
# Best model found at 13949 th iteration with training loss = 0.0250
# Best model found at 13950 th iteration with training loss = 0.0251
#  Epoch: 14101 	 BC Loss: 0.0260	 PDE Loss: 0.0024 	 Loss: 0.0284
#  Epoch: 14401 	 BC Loss: 0.0254	 PDE Loss: 0.0002 	 Loss: 0.0256
# Best model found at 14419 th iteration with training loss = 0.0250
# Best model found at 14420 th iteration with training loss = 0.0250
# Best model found at 14421 th iteration with training loss = 0.0250
# Best model found at 14422 th iteration with training loss = 0.0249
# Best model found at 14423 th iteration with training loss = 0.0249
# Best model found at 14424 th iteration with training loss = 0.0249
# Best model found at 14425 th iteration with training loss = 0.0249
# Best model found at 14426 th iteration with training loss = 0.0249
# Best model found at 14427 th iteration with training loss = 0.0249
#  Epoch: 14701 	 BC Loss: 0.0252	 PDE Loss: 0.0007 	 Loss: 0.0259
# Best model found at 14778 th iteration with training loss = 0.0248
# Best model found at 14779 th iteration with training loss = 0.0248
# Best model found at 14780 th iteration with training loss = 0.0248
# Best model found at 14783 th iteration with training loss = 0.0248
#  Epoch: 15001 	 BC Loss: 0.0248	 PDE Loss: 0.0025 	 Loss: 0.0273
#  Epoch: 15301 	 BC Loss: 0.0273	 PDE Loss: 0.0012 	 Loss: 0.0285
# Best model found at 15376 th iteration with training loss = 0.0247
# Best model found at 15377 th iteration with training loss = 0.0247
# Best model found at 15381 th iteration with training loss = 0.0247
# Best model found at 15382 th iteration with training loss = 0.0247
#  Epoch: 15601 	 BC Loss: 0.0245	 PDE Loss: 0.0078 	 Loss: 0.0323
# Best model found at 15832 th iteration with training loss = 0.0247
# Best model found at 15833 th iteration with training loss = 0.0246
# Best model found at 15834 th iteration with training loss = 0.0246
#  Epoch: 15901 	 BC Loss: 0.0249	 PDE Loss: 0.0002 	 Loss: 0.0250
# Best model found at 16011 th iteration with training loss = 0.0246
# Best model found at 16012 th iteration with training loss = 0.0246
# Best model found at 16013 th iteration with training loss = 0.0246
# Best model found at 16014 th iteration with training loss = 0.0246
# Best model found at 16015 th iteration with training loss = 0.0245
# Best model found at 16016 th iteration with training loss = 0.0244
# Best model found at 16017 th iteration with training loss = 0.0245
# Best model found at 16053 th iteration with training loss = 0.0243
# Best model found at 16059 th iteration with training loss = 0.0242
# Best model found at 16065 th iteration with training loss = 0.0242
# Best model found at 16066 th iteration with training loss = 0.0240
# Best model found at 16067 th iteration with training loss = 0.0241
#  Epoch: 16201 	 BC Loss: 0.0251	 PDE Loss: 0.0029 	 Loss: 0.0279
#  Epoch: 16501 	 BC Loss: 0.0278	 PDE Loss: 0.0020 	 Loss: 0.0298
#  Epoch: 16801 	 BC Loss: 0.0263	 PDE Loss: 0.0005 	 Loss: 0.0268
#  Epoch: 17101 	 BC Loss: 0.0239	 PDE Loss: 0.0004 	 Loss: 0.0243
# Best model found at 17104 th iteration with training loss = 0.0240
# Best model found at 17105 th iteration with training loss = 0.0240
# Best model found at 17110 th iteration with training loss = 0.0240
# Best model found at 17111 th iteration with training loss = 0.0239
# Best model found at 17112 th iteration with training loss = 0.0239
# Best model found at 17113 th iteration with training loss = 0.0238
# Best model found at 17114 th iteration with training loss = 0.0238
# Best model found at 17115 th iteration with training loss = 0.0238
#  Epoch: 17401 	 BC Loss: 0.0245	 PDE Loss: 0.0019 	 Loss: 0.0264
# Best model found at 17633 th iteration with training loss = 0.0238
# Best model found at 17634 th iteration with training loss = 0.0237
#  Epoch: 17701 	 BC Loss: 0.0331	 PDE Loss: 0.0028 	 Loss: 0.0359
#  Epoch: 18001 	 BC Loss: 0.0241	 PDE Loss: 0.0016 	 Loss: 0.0257
#  Epoch: 18301 	 BC Loss: 0.0242	 PDE Loss: 0.0001 	 Loss: 0.0243
#  Epoch: 18601 	 BC Loss: 0.0336	 PDE Loss: 0.0089 	 Loss: 0.0425
#  Epoch: 18901 	 BC Loss: 0.0241	 PDE Loss: 0.0002 	 Loss: 0.0243
# Best model found at 18917 th iteration with training loss = 0.0237
# Best model found at 18918 th iteration with training loss = 0.0237
# Best model found at 18919 th iteration with training loss = 0.0237
#  Epoch: 19201 	 BC Loss: 0.0241	 PDE Loss: 0.0038 	 Loss: 0.0279
# Best model found at 19381 th iteration with training loss = 0.0237
# Best model found at 19382 th iteration with training loss = 0.0237
# Best model found at 19388 th iteration with training loss = 0.0236
# Best model found at 19389 th iteration with training loss = 0.0235
# Best model found at 19390 th iteration with training loss = 0.0235
#  Epoch: 19501 	 BC Loss: 0.0367	 PDE Loss: 0.0081 	 Loss: 0.0447
# Best model found at 19698 th iteration with training loss = 0.0235
# Best model found at 19703 th iteration with training loss = 0.0235
# Best model found at 19704 th iteration with training loss = 0.0234
# Best model found at 19705 th iteration with training loss = 0.0234
#  Epoch: 19801 	 BC Loss: 0.0237	 PDE Loss: 0.0017 	 Loss: 0.0255
#  Epoch: 20101 	 BC Loss: 0.0240	 PDE Loss: 0.0003 	 Loss: 0.0242
# Best model found at 20128 th iteration with training loss = 0.0234
# Best model found at 20129 th iteration with training loss = 0.0234
# Best model found at 20130 th iteration with training loss = 0.0234
# Best model found at 20274 th iteration with training loss = 0.0234
# Best model found at 20275 th iteration with training loss = 0.0233
# Best model found at 20370 th iteration with training loss = 0.0233
# Best model found at 20371 th iteration with training loss = 0.0233
# Best model found at 20372 th iteration with training loss = 0.0233
#  Epoch: 20401 	 BC Loss: 0.0240	 PDE Loss: 0.0020 	 Loss: 0.0260
# Best model found at 20450 th iteration with training loss = 0.0232
#  Epoch: 20701 	 BC Loss: 0.0232	 PDE Loss: 0.0001 	 Loss: 0.0234
# Best model found at 20998 th iteration with training loss = 0.0231
# Best model found at 20999 th iteration with training loss = 0.0231
#  Epoch: 21001 	 BC Loss: 0.0230	 PDE Loss: 0.0002 	 Loss: 0.0232
#  Epoch: 21301 	 BC Loss: 0.0245	 PDE Loss: 0.0010 	 Loss: 0.0255
#  Epoch: 21601 	 BC Loss: 0.0281	 PDE Loss: 0.0248 	 Loss: 0.0529
#  Epoch: 21901 	 BC Loss: 0.0230	 PDE Loss: 0.0004 	 Loss: 0.0234
#  Epoch: 22201 	 BC Loss: 0.0288	 PDE Loss: 0.0019 	 Loss: 0.0307
# Best model found at 22238 th iteration with training loss = 0.0231
# Best model found at 22243 th iteration with training loss = 0.0230
# Best model found at 22244 th iteration with training loss = 0.0230
#  Epoch: 22501 	 BC Loss: 0.0329	 PDE Loss: 0.0013 	 Loss: 0.0342
#  Epoch: 22801 	 BC Loss: 0.0322	 PDE Loss: 0.0039 	 Loss: 0.0361
#  Epoch: 23101 	 BC Loss: 0.0282	 PDE Loss: 0.0026 	 Loss: 0.0308
#  Epoch: 23401 	 BC Loss: 0.0282	 PDE Loss: 0.0008 	 Loss: 0.0290
#  Epoch: 23701 	 BC Loss: 0.0239	 PDE Loss: 0.0002 	 Loss: 0.0241
#  Epoch: 24001 	 BC Loss: 0.0231	 PDE Loss: 0.0011 	 Loss: 0.0242
# Best model found at 24014 th iteration with training loss = 0.0229
# Best model found at 24015 th iteration with training loss = 0.0229
# Best model found at 24016 th iteration with training loss = 0.0229
# Best model found at 24017 th iteration with training loss = 0.0229
# Best model found at 24018 th iteration with training loss = 0.0229
#  Epoch: 24301 	 BC Loss: 0.0236	 PDE Loss: 0.0006 	 Loss: 0.0242
#  Epoch: 24601 	 BC Loss: 0.0228	 PDE Loss: 0.0024 	 Loss: 0.0253
#  Epoch: 24901 	 BC Loss: 0.0228	 PDE Loss: 0.0001 	 Loss: 0.0229
# Best model found at 24900 th iteration with training loss = 0.0229
# Best model found at 25029 th iteration with training loss = 0.0229
# Best model found at 25030 th iteration with training loss = 0.0228
# Best model found at 25031 th iteration with training loss = 0.0228
# Best model found at 25165 th iteration with training loss = 0.0228
# Best model found at 25166 th iteration with training loss = 0.0228
# Best model found at 25167 th iteration with training loss = 0.0228
# Best model found at 25168 th iteration with training loss = 0.0228
# Best model found at 25169 th iteration with training loss = 0.0228
#  Epoch: 25201 	 BC Loss: 0.0365	 PDE Loss: 0.0044 	 Loss: 0.0409
#  Epoch: 25501 	 BC Loss: 0.0229	 PDE Loss: 0.0002 	 Loss: 0.0232
# Best model found at 25635 th iteration with training loss = 0.0228
# Best model found at 25636 th iteration with training loss = 0.0228
# Best model found at 25640 th iteration with training loss = 0.0227
# Best model found at 25641 th iteration with training loss = 0.0227
# Best model found at 25642 th iteration with training loss = 0.0227
#  Epoch: 25801 	 BC Loss: 0.0228	 PDE Loss: 0.0004 	 Loss: 0.0232
# Best model found at 25992 th iteration with training loss = 0.0227
# Best model found at 25993 th iteration with training loss = 0.0226
# Best model found at 25994 th iteration with training loss = 0.0226
# Best model found at 25995 th iteration with training loss = 0.0226
#  Epoch: 26101 	 BC Loss: 0.0298	 PDE Loss: 0.0017 	 Loss: 0.0315
#  Epoch: 26401 	 BC Loss: 0.0233	 PDE Loss: 0.0006 	 Loss: 0.0239
#  Epoch: 26701 	 BC Loss: 0.0294	 PDE Loss: 0.0007 	 Loss: 0.0301
#  Epoch: 27001 	 BC Loss: 0.0277	 PDE Loss: 0.0002 	 Loss: 0.0279
# Best model found at 27195 th iteration with training loss = 0.0226
# Best model found at 27196 th iteration with training loss = 0.0225
#  Epoch: 27301 	 BC Loss: 0.0229	 PDE Loss: 0.0001 	 Loss: 0.0231
#  Epoch: 27601 	 BC Loss: 0.0236	 PDE Loss: 0.0042 	 Loss: 0.0277
#  Epoch: 27901 	 BC Loss: 0.0246	 PDE Loss: 0.0034 	 Loss: 0.0280
# Best model found at 28020 th iteration with training loss = 0.0225
# Best model found at 28021 th iteration with training loss = 0.0225
# Best model found at 28025 th iteration with training loss = 0.0224
# Best model found at 28026 th iteration with training loss = 0.0224
# Best model found at 28029 th iteration with training loss = 0.0224
# Best model found at 28030 th iteration with training loss = 0.0224
# Best model found at 28031 th iteration with training loss = 0.0224
#  Epoch: 28201 	 BC Loss: 0.0235	 PDE Loss: 0.0014 	 Loss: 0.0248
# Best model found at 28388 th iteration with training loss = 0.0224
# Best model found at 28389 th iteration with training loss = 0.0223
# Best model found at 28392 th iteration with training loss = 0.0223
# Best model found at 28393 th iteration with training loss = 0.0223
# Best model found at 28394 th iteration with training loss = 0.0222
# Best model found at 28395 th iteration with training loss = 0.0222
# Best model found at 28396 th iteration with training loss = 0.0222
#  Epoch: 28501 	 BC Loss: 0.0232	 PDE Loss: 0.0029 	 Loss: 0.0260
#  Epoch: 28801 	 BC Loss: 0.0233	 PDE Loss: 0.0001 	 Loss: 0.0234
# Best model found at 29038 th iteration with training loss = 0.0222
# Best model found at 29039 th iteration with training loss = 0.0222
# Best model found at 29040 th iteration with training loss = 0.0222
# Best model found at 29042 th iteration with training loss = 0.0222
# Best model found at 29043 th iteration with training loss = 0.0222
# Best model found at 29044 th iteration with training loss = 0.0221
# Best model found at 29045 th iteration with training loss = 0.0221
# Best model found at 29046 th iteration with training loss = 0.0221
# Best model found at 29047 th iteration with training loss = 0.0221
# Best model found at 29048 th iteration with training loss = 0.0221
# Best model found at 29049 th iteration with training loss = 0.0221
#  Epoch: 29101 	 BC Loss: 0.0367	 PDE Loss: 0.0051 	 Loss: 0.0418
#  Epoch: 29401 	 BC Loss: 0.0228	 PDE Loss: 0.0008 	 Loss: 0.0236
#  Epoch: 29701 	 BC Loss: 0.0229	 PDE Loss: 0.0019 	 Loss: 0.0247
# Training finished
# Training time(s): 2259.12
# Final loss: 0.02402137592434883

# %%
#''' Model Accuracy ''' 
#best_error_vec, best_u_pred = bestPINN.test() # use the best model to evaluate the test error
#final_error_vec, final_u_pred = PINN.test()
#print('Best Test Error: %.5f'  % (best_error_vec))
#print('Final Test Error: %.5f'  % (final_error_vec))

best_u_pred = bestPINN.test()
final_u_pred = PINN.test()

# %%
print(PINN.state_dict().keys())
print(PINN.state_dict()['linears.4.weight'])
print(bestPINN.state_dict()['linears.4.weight'])
# Out:
# odict_keys(['linears.0.weight', 'linears.0.bias', 'linears.1.weight', 'linears.1.bias', 'linears.2.weight', 'linears.2.bias', 'linears.3.weight', 'linears.3.bias', 'linears.4.weight', 'linears.4.bias'])
# tensor([[ 2.6024e-04, -3.7044e-02,  4.9143e-05,  ...,  2.5265e-02,
#           1.8481e-02,  4.9998e-02]], device='cuda:0')
# tensor([[ 6.2784e-05, -3.7234e-02, -5.9124e-05,  ...,  2.5225e-02,
#           1.8481e-02,  5.0154e-02]], device='cuda:0')

# %%
#solutionplot(u_pred,X_u_train.cpu().detach().numpy(),u_train.cpu().detach().numpy())

# %%
#best_error_vec = best_error_vec.cpu().detach().numpy() # detach from GPU to CPU
#final_error_vec = final_error_vec.cpu().detach().numpy() # detach from GPU to CPU

# %% [markdown]
# # Save arrays in npy file

# %%
## Saving list
# Input nodes: nodes
# ground truth: temperature
# max_iter = max_iter
# best iteration number: best_iter
# best model: best_error_vec, best_u_pred 
# final model: final_error_vec, final_u_pred
# Loss arrays: total_loss_array, BC_loss_array, PDE_loss_array, test_error_array

np.savez('Results_Data_'+str(max_iter)+'_iteration.npz', 
         nodes = nodes, 
         temperature = temperature,
         max_iter = max_iter,
         #best_error_vec = best_error_vec,
         best_u_pred = best_u_pred,
         #final_error_vec = final_error_vec,
         final_u_pred = final_u_pred,
         best_iter = best_iter,
         PDE_loss_array = PDE_loss_array,
         BC_loss_array = BC_loss_array,
         total_loss_array = total_loss_array)
         #test_error_array = test_error_array)

# %%
# Plot test error (no test error)
#plt.figure(1,figsize=(8, 8), dpi=80)
# plt.figure(1,dpi=300)
# iter_array = np.arange(0,max_iter)
# plt.plot(iter_array,test_error_array)
# plt.plot([best_iter,best_iter],[0,best_error_vec],'o-k')
# plt.xlabel('Epoch')
# plt.ylabel('Test Error')
# plt.legend(['Best error: ' +str(best_error_vec),'best iteration: '+str(best_iter)])
# plt.ylim(bottom=0)  # https://matplotlib.org/3.5.0/api/_as_gen/matplotlib.pyplot.ylim.html
#plt.savefig('Test_error_'+str(max_iter)+'_iteration.jpg',dpi=150)

# %%
# Detach loss tensors
#print(np.shape(total_loss_array))
#print(total_loss_array)
#print(BC_loss_array)
#print(PDE_loss_array)
#print(np.array_equal(PDE_loss_array,BC_loss_array))

# %%
plt.figure(2, dpi=80)

iter_array = np.arange(0,max_iter)
plt.plot(iter_array,total_loss_array)
plt.plot(iter_array,BC_loss_array)
plt.plot(iter_array, PDE_loss_array)
plt.legend(['Total Loss','BC Loss','PDE Loss'])
plt.yscale('log')
plt.xlabel('Epoch')
plt.ylabel('Loss')
#plt.savefig('loss_'+str(max_iter)+'_iteration.jpg',dpi=150)
# Out:
# Text(0, 0.5, 'Loss')

# %%
# For plotting nicer plot we use plt.imshow().
# First we convert the unstructured data to mesh grid then use plt.imshow()

# %%
# def return_indices(lower_limit_k, upper_limit_k, k):
#     # returns indices for k (conductivity) between lower_limit_k and upper_limit_k
#     indices = []
#     for index,item in enumerate(k):
#         if upper_limit_k>item>lower_limit_k:
#             indices.append(index)
#     # move out of the function to see the plot 
#     #print(np.shape(indices))
#     #plt.plot(k[indices])
#     return indices

# %%
#print(np.shape(u_pred))
# from mpl_toolkits.mplot3d import Axes3D
# from matplotlib import cm
# fig = plt.figure(dpi=300)
# ax = fig.add_subplot(111)#, projection='3d')
# n_points = 300
# x = np.linspace(lb[0], ub[0], n_points)
# y = np.linspace(lb[1], ub[1], n_points)
# X, Y = np.meshgrid(x,y)

# UU_star = griddata(nodes, temperature.flatten(), (X, Y), method='cubic')
# sc = ax.imshow(UU_star, interpolation='nearest', cmap='jet', 
#                   extent=[nodes[:,0].min(), nodes[:,0].max(), nodes[:,1].min(), nodes[:,1].max()], 
#                   origin='lower', aspect='auto')

# #sc = ax.scatter(nodes[:,0], nodes[:,1], c = temperature,s=3, cmap=cm.jet)
# plt.colorbar(sc)
# plt.xlabel('x')
# plt.ylabel('y')
#ax.set_zlabel('z')
#plt.title('Temperature distribution')
#plt.savefig('Exact.jpg', dpi = 200)

# %%
# np.unique(nodes[:,2])

# %%
fig = plt.figure(figsize=(12,12))
ax = fig.add_subplot(111, projection='3d')
sc = ax.scatter(nodes[:,0], nodes[:,1], nodes[:,2], c = temperature, cmap=cm.jet, vmin=0, vmax=1)
plt.colorbar(sc)
sc.cmap.set_under('k')
sc.cmap.set_over('k')
plt.xlabel('x')
plt.ylabel('y')
ax.set_zlabel('z')
# Out:
# /tmp/ipykernel_15416/3996053871.py:5: MatplotlibDeprecationWarning: You are modifying the state of a globally registered colormap. This has been deprecated since 3.3 and in 3.6, you will not be able to modify a registered colormap in-place. To remove this warning, you can make a copy of the colormap first. cmap = mpl.cm.get_cmap("jet").copy()
#   sc.cmap.set_under('k')
# /tmp/ipykernel_15416/3996053871.py:6: MatplotlibDeprecationWarning: You are modifying the state of a globally registered colormap. This has been deprecated since 3.3 and in 3.6, you will not be able to modify a registered colormap in-place. To remove this warning, you can make a copy of the colormap first. cmap = mpl.cm.get_cmap("jet").copy()
#   sc.cmap.set_over('k')
# Text(0.5, 0, 'z')

# %%
fig = plt.figure(figsize=(12,12))
ax = fig.add_subplot(111, projection='3d')
sc = ax.scatter(boundary_nodal_coordinates[:,0], boundary_nodal_coordinates[:,1], boundary_nodal_coordinates[:,2], c = boundary_solution, cmap=cm.jet, vmin=0, vmax=1)
plt.colorbar(sc)
sc.cmap.set_under('k')
sc.cmap.set_over('k')
plt.xlabel('x')
plt.ylabel('y')
ax.set_zlabel('z')
# Out:
# /tmp/ipykernel_15416/1429878910.py:5: MatplotlibDeprecationWarning: You are modifying the state of a globally registered colormap. This has been deprecated since 3.3 and in 3.6, you will not be able to modify a registered colormap in-place. To remove this warning, you can make a copy of the colormap first. cmap = mpl.cm.get_cmap("jet").copy()
#   sc.cmap.set_under('k')
# /tmp/ipykernel_15416/1429878910.py:6: MatplotlibDeprecationWarning: You are modifying the state of a globally registered colormap. This has been deprecated since 3.3 and in 3.6, you will not be able to modify a registered colormap in-place. To remove this warning, you can make a copy of the colormap first. cmap = mpl.cm.get_cmap("jet").copy()
#   sc.cmap.set_over('k')
# Text(0.5, 0, 'z')

# %%
#indices = return_indices(lower_limit_k = 0.01, upper_limit_k=1.06, k=nodes[:,2])

fig = plt.figure(figsize=(12,12))
ax = fig.add_subplot(111, projection='3d')
sc = ax.scatter(nodes[:,0], nodes[:,1], nodes[:,2], c = best_u_pred[:], cmap=cm.jet, vmin=0, vmax=1)
plt.colorbar(sc)
sc.cmap.set_under('k')
sc.cmap.set_over('k')
plt.xlabel('x')
plt.ylabel('y')
ax.set_zlabel('z')
#plt.title('Temperature distribution')
#plt.savefig('Iteration_'+str(max_iter)+'_PINN_predicted.jpg', dpi = 200)
# Out:
# /tmp/ipykernel_15416/3107256919.py:7: MatplotlibDeprecationWarning: You are modifying the state of a globally registered colormap. This has been deprecated since 3.3 and in 3.6, you will not be able to modify a registered colormap in-place. To remove this warning, you can make a copy of the colormap first. cmap = mpl.cm.get_cmap("jet").copy()
#   sc.cmap.set_under('k')
# /tmp/ipykernel_15416/3107256919.py:8: MatplotlibDeprecationWarning: You are modifying the state of a globally registered colormap. This has been deprecated since 3.3 and in 3.6, you will not be able to modify a registered colormap in-place. To remove this warning, you can make a copy of the colormap first. cmap = mpl.cm.get_cmap("jet").copy()
#   sc.cmap.set_over('k')
# Text(0.5, 0, 'z')

# %%
# True solution

# fig = plt.figure(figsize=(12,12))
# ax = fig.add_subplot(111)#, projection='3d')
 
# sc = ax.scatter(nodes[:,0], nodes[:,1], c = abs(best_u_pred-temperature), cmap=cm.jet)
# plt.colorbar(sc)
# #sc.cmap.set_under('k')
# #sc.cmap.set_over('k')
# plt.xlabel('x')
# plt.ylabel('y')
# #ax.set_zlabel('z')
# #plt.title('Temperature distribution')
# #plt.savefig('iteration_'+str(max_iter)+'_absolute-error.jpg', dpi = 200)

# %% [markdown]
# # Continue training

# %%
#PINN.loss_BC(X_u_train, u_train)
#PINN.loss_PDE(X_f_train)

# %%
additional_iter = 20000

start_time = time.time()
BC_loss_array = np.zeros(additional_iter)
PDE_loss_array = np.zeros(additional_iter)
total_loss_array = np.zeros(additional_iter)

for i in range(additional_iter):
    # For updated model parameters of PINN() object
    BC_loss =  PINN.loss_BC(X_u_train, u_train) # BC loss
    PDE_loss = PINN.loss_PDE(X_f_train) # PDE loss

    total_loss = BC_loss + PDE_loss #PINN.loss(BC_loss, PDE_loss, X_f_train)
           
    optimizer.zero_grad()     # zeroes the gradient in each epoch
    
    total_loss.backward() # backprop the total loss and store in .grad()

    optimizer.step() # update parameters
    
    BC_loss_array [i] = BC_loss
    PDE_loss_array[i] = PDE_loss
    total_loss_array[i] = total_loss  
    
    if i % (additional_iter/10) == 0:
        print(f" Epoch: {i+1} \t BC Loss: {BC_loss:0.4f}\t PDE Loss: {PDE_loss:0.4f} \t Loss: {total_loss:0.4f}")
    if total_loss < 1: # compromise
        print(f'Loss converged in {i} Epochs ')
        break
#     if i % (max_iter/10) == 0:

#         error_vec, _ = PINN.test()

#         print(loss,error_vec)
else:
    print('Training finished')
    elapsed = time.time() - start_time                
    print('Training time: %.2f' % (elapsed))
    print(f"Final loss: {total_loss}")


''' Model Accuracy ''' 
error_vec, u_pred = PINN.test()

print('Test Error: %.5f'  % (error_vec))

# %%
plt.figure(1,figsize=(8, 8), dpi=80)

iter_array = np.arange(0,additional_iter)
plt.plot(iter_array,total_loss_array)
plt.plot(iter_array,BC_loss_array)
plt.plot(iter_array, PDE_loss_array)
plt.legend(['Total Loss','BC Loss','PDE Loss'])
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.savefig('loss_20000_Epoch.jpg',dpi=150)

# %%
print(np.shape(u_pred))

# %%
fig = plt.figure(figsize=(12,12))
ax = fig.add_subplot(111, projection='3d')
sc = ax.scatter(nodes[:,0], nodes[:,1], nodes[:,2], c = u_pred, cmap=cm.jet, vmin=100, vmax=200)
plt.colorbar(sc)
sc.cmap.set_under('k')
sc.cmap.set_over('k')
plt.xlabel('x')
plt.ylabel('y')
ax.set_zlabel('z')
plt.title('Temperature distribution')
plt.savefig('PINN_predicted.jpg', dpi = 200)

# %%
fig = plt.figure(figsize=(12,12))
ax = fig.add_subplot(111, projection='3d')
 
sc = ax.scatter(nodes[:,0], nodes[:,1], nodes[:,2], c = abs(u_pred-temperature), cmap=cm.jet)
plt.colorbar(sc)
#sc.cmap.set_under('k')
#sc.cmap.set_over('k')
plt.xlabel('x')
plt.ylabel('y')
ax.set_zlabel('z')
plt.title('Temperature distribution')
plt.savefig('absolute-error.jpg', dpi = 200)
